# %%
import pandas as pd

# %%
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 


df = pd.DataFrame(data)
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %% [markdown]
# - **Uppercase Lowercase shift in df**

# %%
df["Address"] = df["Address"].str.lower()
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      delhi           Msc
# 1  Princi   24     kanpur            MA
# 2  Gaurav   22  allahabad           MCA
# 3    Anuj   32    kannauj           Phd

# %%
df["Address"] = df["Address"].str.upper()
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      DELHI           Msc
# 1  Princi   24     KANPUR            MA
# 2  Gaurav   22  ALLAHABAD           MCA
# 3    Anuj   32    KANNAUJ           Phd

# %% [markdown]
# - **Split and replace**

# %%
df["Address"] = df["Address"].str.split("A", n=1).str[1]
df.dropna(inplace=True)
df
# Out:
#      Name  Age   Address Qualification
# 1  Princi   24      NPUR            MA
# 2  Gaurav   22  LLAHABAD           MCA
# 3    Anuj   32     NNAUJ           Phd

# %%
df["Age"] = df["Age"].replace(24, "Twenty Four")
df
# Out:
#      Name          Age   Address Qualification
# 1  Princi  Twenty Four      NPUR            MA
# 2  Gaurav           22  LLAHABAD           MCA
# 3    Anuj           32     NNAUJ           Phd

# %% [markdown]
# - **Concatenation**

# %%
df["Name"] = df["Name"].str.cat(df["Address"], sep='-')
df.drop()
# Out:
#               Name          Age   Address Qualification
# 1      Princi-NPUR  Twenty Four      NPUR            MA
# 2  Gaurav-LLAHABAD           22  LLAHABAD           MCA
# 3       Anuj-NNAUJ           32     NNAUJ           Phd
