# %% [markdown]
# ### ***n_gram bag of words***
# - Language modeling involves determining the probability of a sequence of words.
# - Counts the number / frequency of each of the sequence of words of its trained vocab in the given text
# - Thus the whole text is vectorized
#
# > This can be implemented by **count vectorizer of sklearn with n_gram props**
# ***
# ***Example***
# - **I am working on machine learning => work machine learn**
# - **I am working on learning machine => work learn machine**
#
# After lemmitisation and stop words removing the count vectorisation with single words will be same -> `Similar setence`
# But they are not actually! we can detect that if we consider `bigram`, these `machine learn` and `learn machine` will differ!

# %%
import pandas as pd
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

# %%
# data 
data = pd.read_csv("Fake.csv")
data.head()
# Out:
#                                                 Text label
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake
# 1  U.S. conservative leader optimistic of common ...  Real
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake
# 4  Democrats say Trump agrees to work on immigrat...  Real

# %%
data["label"] = data["label"].apply(lambda x: 1 if x == "Real" else 0)
data
# Out:
#                                                    Text  label
# 0      Top Trump Surrogate BRUTALLY Stabs Him In The...      0
# 1     U.S. conservative leader optimistic of common ...      1
# 2     Trump proposes U.S. tax overhaul, stirs concer...      1
# 3      Court Forces Ohio To Allow Millions Of Illega...      0
# 4     Democrats say Trump agrees to work on immigrat...      1
# ...                                                 ...    ...
# 9895   Wikileaks Admits To Screwing Up IMMENSELY Wit...      0
# 9896  Trump consults Republican senators on Fed chie...      1
# 9897  Trump lawyers say judge lacks jurisdiction for...      1
# 9898   WATCH: Right-Wing Pastor Falsely Credits Trum...      0
# 9899   Sean Spicer HILARIOUSLY Branded As Chickensh*...      0
#
# [9900 rows x 2 columns]

# %%
# data checking
data["label"].value_counts()
# Out:
# label
# 0    5000
# 1    4900
# Name: count, dtype: int64

# %%
# train test split
from sklearn.model_selection import train_test_split
train_text, test_text, train_label, test_label = train_test_split(data["Text"], data["label"], test_size=0.2, random_state=42)

# %%
train_label
# Out:
# 1665    1
# 1416    1
# 7298    1
# 4700    1
# 6192    0
#        ..
# 5734    0
# 5191    0
# 5390    0
# 860     1
# 7270    1
# Name: label, Length: 7920, dtype: int64

# %%
train_text
# Out:
# 1665    As new fiscal year dawns, hope for Illinois bu...
# 1416    Schumer says U.S. budget deal doable if Trump ...
# 7298    NRA calls for more regulation after Vegas shoo...
# 4700    White House says Tillerson to remain as secret...
# 6192     Scientists Scramble To Copy Climate Data Befo...
#                               ...
# 5734     WATCH: Hannity Loses His Sh*t And Refers To H...
# 5191     Sean Hannity Just Showed EXACTLY How Delusion...
# 5390     WATCH: CNN Host Makes Trump’s Campaign Manage...
# 860     Democratic senator lifts hold on Trump antitru...
# 7270    'Unremarkable' Virginia attacker shows difficu...
# Name: Text, Length: 7920, dtype: object

# %% [markdown]
# ***text modification***

# %%
nlp = spacy.load('en_core_web_sm')
nlp.vocab["not"].is_stop = False

# %%
def modify_text (text):
    doc = nlp(text)
    # lemmitization, stop words & puncs remiving
    modified_tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    return modified_tokens

# %%
# train_text["modified_text"] = train_text["Text"].apply(modify_text)

# %%
# Process all texts efficiently
""" docs = nlp.pipe(data["Text"])
data["coded_text"] = [
    [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    for doc in docs
]
 """
# Out:
# ' docs = nlp.pipe(data["Text"])\ndata["coded_text"] = [\n    [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]\n    for doc in docs\n]\n '

# %% [markdown]
# ***vectorization***

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# `monogram`

# %%
vectorizer1 = CountVectorizer()

# %%
vectorizer1.fit(train_text)
# Out:
# CountVectorizer()

# %%
vectorizer1.vocabulary_
# Out:
# {'as': 5823,
#  'new': 32914,
#  'fiscal': 19178,
#  'year': 52290,
#  'dawns': 13787,
#  'hope': 23344,
#  'for': 19590,
#  'illinois': 24036,
#  'budget': 9080,
#  'dims': 15051,
#  'chicago': 10589,
#  'reuters': 40227,
#  'risking': 40572,
#  'historic': 23055,
#  'drop': 16161,
#  'to': 47559,
#  'junk': 26497,
#  'bond': 8269,
#  'status': 44878,
#  'began': 7174,
#  'its': 25519,
#  'third': 47191,
#  'straight': 45244,
#  'without': 51687,
#  'on': 34179,
#  'saturday': 41662,
#  'political': 36624,
#  'maneuvering': 29787,
#  'dimmed': 15047,
#  'hopes': 23351,
#  'bipartisan': 7736,
#  'spending': 44386,
#  'and': 5130,
#  'revenue': 40254,
#  'package': 34923,
#  'anytime': 5406,
#  'soon': 44120,
#  'while': 51308,
#  'the': 46982,
#  'house': 23458,
#  'scheduled': 41853,
#  'session': 42535,
#  'sunday': 45727,
#  'take': 46317,
#  'up': 49645,
#  'senate': 42374,
#  'is': 25415,
#  'not': 33455,
#  'slated': 43597,
#  'return': 40206,
#  'until': 49585,
#  'monday': 31711,
#  'nation': 32572,
#  'fifth': 19005,
#  'largest': 27943,
#  'state': 44837,
#  'has': 22371,
#  'lacked': 27745,
#  'full': 20152,
#  'operating': 34262,
#  'since': 43331,
#  'july': 26471,
#  '2015': 854,
#  'under': 49027,
#  'warning': 50865,
#  'from': 20038,
#  'that': 46969,
#  'it': 25489,
#  'will': 51510,
#  'creditworthiness': 12974,
#  'lowest': 29205,
#  'of': 33971,
#  'any': 5397,
#  'in': 24310,
#  'history': 23059,
#  'if': 23941,
#  'fails': 18452,
#  'pass': 35271,
#  '2018': 2006,
#  'starts': 44825,
#  'address': 3995,
#  'chronic': 10798,
#  'structural': 45402,
#  'deficit': 14146,
#  'talks': 46358,
#  'between': 7518,
#  'democrats': 14350,
#  'who': 51395,
#  'control': 12397,
#  'republicans': 39886,
#  'had': 21983,
#  'shown': 43070,
#  'signs': 43244,
#  'progress': 37530,
#  'both': 8435,
#  'sides': 43177,
#  'rallied': 38541,
#  'behind': 7208,
#  '36': 2529,
#  'billion': 7665,
#  'blueprint': 8064,
#  'friday': 19990,
#  'were': 51194,
#  'poised': 36573,
#  'build': 9114,
#  'positive': 36827,
#  'movement': 32020,
#  'rare': 38678,
#  'fourth': 19779,
#  'holiday': 23188,
#  'weekend': 51106,
#  'legislative': 28309,
#  'instead': 24933,
#  'tensions': 46801,
#  'broke': 8911,
#  'out': 34554,
#  'floor': 19404,
#  'republican': 39884,
#  'leader': 28163,
#  'jim': 26069,
#  'durkin': 16367,
#  'democratic': 14347,
#  'speaker': 44298,
#  'michael': 30999,
#  'madigan': 29526,
#  'initially': 24778,
#  'informed': 24707,
#  'chamber': 10321,
#  'no': 33270,
#  'votes': 50583,
#  'would': 51895,
#  'be': 7051,
#  'taken': 46326,
#  'saying': 41722,
#  'we': 51021,
#  'll': 28897,
#  'gavel': 20523,
#  'at': 6044,
#  'some': 44076,
#  'point': 36561,
#  'me': 30531,
#  'does': 15718,
#  'send': 42394,
#  'message': 30892,
#  'illinoisans': 24038,
#  're': 38798,
#  'prepared': 37181,
#  'bring': 8840,
#  'this': 47201,
#  'resolution': 40014,
#  'time': 47403,
#  'said': 41385,
#  'party': 35262,
#  'proxy': 37775,
#  'governor': 21316,
#  'bruce': 8975,
#  'rauner': 38739,
#  'stayed': 44894,
#  'sidelines': 43174,
#  'recent': 39026,
#  'negotiations': 32780,
#  'walked': 50770,
#  'off': 33976,
#  'short': 43003,
#  'later': 27997,
#  'shout': 43037,
#  'representative': 39852,
#  'grant': 21434,
#  'wehrli': 51120,
#  'suburban': 45586,
#  'by': 9381,
#  'late': 27992,
#  'afternoon': 4282,
#  'reversed': 40266,
#  'course': 12773,
#  'there': 47104,
#  'indeed': 24497,
#  'vote': 50575,
#  'tax': 46552,
#  'increase': 24461,
#  'neglecting': 32768,
#  'mention': 30803,
#  'accompanying': 3785,
#  'local': 28955,
#  'property': 37633,
#  'freeze': 19947,
#  'or': 34352,
#  'workers': 51836,
#  'compensation': 11761,
#  'reforms': 39327,
#  'are': 5655,
#  'two': 48702,
#  'key': 27000,
#  'demands': 14315,
#  'negotiation': 32779,
#  'statement': 44849,
#  'he': 22508,
#  'was': 50896,
#  'encouraged': 17211,
#  'with': 51668,
#  'vowed': 50597,
#  'modeled': 31597,
#  'bill': 7651,
#  'supported': 45822,
#  'made': 29519,
#  'clear': 11089,
#  'his': 23043,
#  'own': 34847,
#  'agreement': 4358,
#  'comprehensive': 11843,
#  'includes': 24418,
#  'contradicting': 12367,
#  'painting': 34979,
#  'dim': 15031,
#  'outlook': 34609,
#  'consensus': 12160,
#  'impasse': 24160,
#  'can': 9615,
#  'only': 34204,
#  'resolved': 40017,
#  'negotiated': 32776,
#  'manner': 29837,
#  'our': 34543,
#  'remain': 39629,
#  'negotiating': 32778,
#  'table': 46238,
#  'schumer': 41933,
#  'says': 41723,
#  'deal': 13869,
#  'doable': 15675,
#  'trump': 48282,
#  'stays': 44897,
#  'washington': 50904,
#  'chuck': 10815,
#  'believes': 7254,
#  'lawmakers': 28102,
#  'could': 12695,
#  'reach': 38801,
#  'term': 46818,
#  'president': 37224,
#  'donald': 15798,
#  'did': 14939,
#  'meddle': 30590,
#  'their': 47036,
#  'poison': 36574,
#  'pill': 36169,
#  'like': 28661,
#  'funding': 20191,
#  'border': 8373,
#  'wall': 50779,
#  'am': 4891,
#  'hopeful': 23346,
#  'get': 20768,
#  'done': 15815,
#  'news': 32934,
#  'conference': 12004,
#  'fly': 19471,
#  'ointment': 34066,
#  'being': 7222,
#  'little': 28837,
#  'heavy': 22626,
#  'handed': 22156,
#  'mixing': 31493,
#  'asking': 5891,
#  'things': 47178,
#  'such': 45614,
#  'so': 43932,
#  'ask': 5884,
#  'him': 22993,
#  'let': 28424,
#  'us': 49758,
#  'do': 15673,
#  'work': 51831,
#  'throw': 47293,
#  'last': 27977,
#  'minute': 31292,
#  'pills': 36178,
#  'undo': 49155,
#  'nra': 33569,
#  'calls': 9550,
#  'more': 31846,
#  'regulation': 39432,
#  'after': 4278,
#  'vegas': 50112,
#  'shooting': 42982,
#  'national': 32573,
#  'rifle': 40476,
#  'association': 5994,
#  'thursday': 47323,
#  'devices': 14808,
#  'allow': 4746,
#  'semi': 42358,
#  'automatic': 6272,
#  'rifles': 40477,
#  'function': 20175,
#  'fully': 20158,
#  'ones': 34192,
#  'need': 32738,
#  'tougher': 47790,
#  'called': 9541,
#  'regulators': 39436,
#  'determine': 14741,
#  'whether': 51301,
#  'bump': 9168,
#  'stock': 45138,
#  'comply': 11824,
#  'federal': 18785,
#  'law': 28089,
#  'calling': 9545,
#  'bureau': 9211,
#  'alcohol': 4567,
#  'tobacco': 47564,
#  'firearms': 19126,
#  'explosives': 18212,
#  'immediately': 24111,
#  'review': 40275,
#  'these': 47138,
#  'powerful': 36949,
#  'gun': 21839,
#  'lobby': 28944,
#  'group': 21662,
#  'designed': 14646,
#  'should': 43031,
#  'subject': 45506,
#  'additional': 3991,
#  'regulations': 39433,
#  'white': 51358,
#  'tillerson': 47390,
#  'secretary': 42215,
#  'rex': 40337,
#  'spokeswoman': 44491,
#  'amid': 4995,
#  'reports': 39840,
#  'removed': 39679,
#  'favor': 18696,
#  'mike': 31106,
#  'pompeo': 36691,
#  'currently': 13335,
#  'cia': 10858,
#  'director': 15113,
#  'when': 51286,
#  'loses': 29127,
#  'confidence': 12019,
#  'someone': 44082,
#  'they': 47156,
#  'longer': 29048,
#  'serve': 42514,
#  'here': 22794,
#  'sarah': 41592,
#  'sanders': 41542,
#  'asked': 5889,
#  'about': 3651,
#  'staff': 44702,
#  'shake': 42659,
#  'scientists': 41952,
#  'scramble': 42026,
#  'copy': 12515,
#  'climate': 11144,
#  'data': 13715,
#  'before': 7169,
#  'make': 29659,
#  'all': 4678,
#  'disappear': 15149,
#  'isn': 25455,
#  'exactly': 17955,
#  'stickler': 45075,
#  'facts': 18420,
#  'convinced': 12448,
#  'change': 10346,
#  'real': 38845,
#  'heck': 22631,
#  'doesn': 15719,
#  'necessarily': 32721,
#  'even': 17871,
#  'believe': 7249,
#  'science': 41946,
#  'maybe': 30323,
#  'global': 21024,
#  'warming': 50856,
#  'just': 26517,
#  'chinese': 10660,
#  'hoax': 23123,
#  'right': 40488,
#  'people': 35667,
#  'picked': 36103,
#  'cabinet': 9442,
#  'far': 18579,
#  'environmentally': 17455,
#  'friendly': 20007,
#  'well': 51168,
#  'have': 22436,
#  'notice': 33479,
#  'taking': 46335,
#  'action': 3903,
#  'scrambling': 42029,
#  'administration': 4056,
#  'chance': 10336,
#  'post': 36845,
#  'efforts': 16742,
#  'include': 24416,
#  'guerrilla': 21772,
#  'archiving': 5647,
#  'event': 17876,
#  'toronto': 47737,
#  'where': 51290,
#  'experts': 18173,
#  'irreplaceable': 25392,
#  'public': 37861,
#  'meetings': 30643,
#  'university': 49353,
#  'pennsylvania': 35650,
#  'focused': 19501,
#  'how': 23482,
#  'download': 15971,
#  'much': 32128,
#  'possible': 36842,
#  'coming': 11616,
#  'weeks': 51111,
#  'collaboration': 11477,
#  'database': 13716,
#  'compiling': 11782,
#  'an': 5074,
#  'online': 34201,
#  'site': 43408,
#  'harbor': 22265,
#  'scientific': 41949,
#  'information': 24702,
#  'nick': 33049,
#  'santos': 41583,
#  'environmental': 17451,
#  'researcher': 39937,
#  'california': 9528,
#  'davis': 13773,
#  'one': 34185,
#  'over': 34674,
#  'started': 44818,
#  'copying': 12517,
#  'government': 21313,
#  'onto': 34216,
#  'server': 42517,
#  'something': 44088,
#  'seemed': 42276,
#  'paranoid': 35145,
#  'sudden': 45624,
#  'seems': 42280,
#  'potentially': 36905,
#  'realistic': 38873,
#  'least': 28219,
#  'you': 52419,
#  'want': 50824,
#  'hedge': 22642,
#  'against': 4294,
#  'doing': 15740,
#  'good': 21201,
#  'thing': 47177,
#  'hopefully': 23347,
#  'leave': 28222,
#  'everything': 17897,
#  'place': 36310,
#  'but': 9310,
#  'planning': 36357,
#  'halpern': 22093,
#  'deputy': 14550,
#  'center': 10202,
#  'democracy': 14342,
#  'advocacy': 4179,
#  'union': 49326,
#  'concerned': 11910,
#  'email': 17005,
#  'head': 22511,
#  'agencies': 4302,
#  'been': 7159,
#  'band': 6699,
#  'conspiracy': 12214,
#  'theorists': 47092,
#  'salivating': 41438,
#  'possibility': 36841,
#  'dismantling': 15347,
#  'research': 39935,
#  'programs': 37529,
#  'years': 52298,
#  'unreasonable': 49481,
#  'think': 47179,
#  'down': 15959,
#  'very': 50210,
#  'dispute': 15424,
#  'wrote': 51994,
#  'fine': 19095,
#  'line': 28729,
#  'best': 7465,
#  'preserve': 37214,
#  'archive': 5643,
#  'websites': 51081,
#  'those': 47237,
#  'dismantle': 15343,
#  'storm': 45213,
#  'castle': 9963,
#  'never': 32897,
#  'intends': 25020,
#  'manipulate': 29819,
#  'located': 28963,
#  'across': 3897,
#  'country': 12753,
#  'aren': 5659,
#  'chances': 10340,
#  'researchers': 39938,
#  'feverishly': 18942,
#  'trying': 48422,
#  'figure': 19018,
#  'ways': 50989,
#  'holding': 23177,
#  'collect': 11491,
#  'vital': 50472,
#  'takes': 46332,
#  'office': 33998,
#  'according': 3798,
#  'organizers': 34422,
#  'preserving': 37217,
#  'protection': 37701,
#  'agency': 4303,
#  'which': 51305,
#  'high': 22926,
#  'risk': 40568,
#  'access': 3755,
#  'deleted': 14248,
#  'water': 50940,
#  'air': 4435,
#  'toxics': 47837,
#  'lawyers': 28115,
#  'legal': 28284,
#  'defense': 14126,
#  'fund': 20183,
#  'available': 6294,
#  'meet': 30641,
#  'american': 4975,
#  'geophysical': 20704,
#  'fall': 18502,
#  'meeting': 30642,
#  'san': 41521,
#  'francisco': 19853,
#  'organization': 34415,
#  'also': 4814,
#  'handing': 22170,
#  'booklets': 8326,
#  'titled': 47506,
#  'handling': 22178,
#  'harassment': 22260,
#  'intimidation': 25169,
#  'pocket': 36531,
#  'guide': 21787,
#  'literally': 28814,
#  'thought': 47240,
#  'day': 13791,
#  'election': 16863,
#  'lauren': 28063,
#  'kurtz': 27617,
#  'executive': 18049,
#  'gotten': 21291,
#  'lot': 29135,
#  'really': 38891,
#  'intended': 25018,
#  'reassuring': 38947,
#  'say': 41717,
#  'game': 20392,
#  'plan': 36346,
#  'help': 22735,
#  'eric': 17579,
#  'holthaus': 23227,
#  'meteorologist': 30926,
#  'describes': 14614,
#  'himself': 22998,
#  'hawk': 22455,
#  'issued': 25478,
#  'call': 9534,
#  'via': 50255,
#  'twitter': 48628,
#  'posted': 36856,
#  'gov': 21306,
#  'don': 15795,
#  'see': 42257,
#  'mountains': 31996,
#  'pouring': 36932,
#  'actually': 3929,
#  'happen': 22230,
#  'alter': 4829,
#  'destroy': 14693,
#  'sets': 42551,
#  'priceless': 37311,
#  'sense': 42421,
#  'gap': 20418,
#  'greatly': 21496,
#  'diminishes': 15039,
#  'usefulness': 49788,
#  'featured': 18776,
#  'image': 24065,
#  'hull': 23592,
#  'negotiate': 32775,
#  '20': 798,
#  'percent': 35693,
#  'corporate': 12585,
#  'rate': 38703,
#  'wealthy': 51038,
#  'americans': 4980,
#  'benefit': 7327,
#  'framework': 19837,
#  'proposal': 37647,
#  'lower': 29200,
#  'wealth': 51034,
#  'told': 47601,
#  'reporters': 39838,
#  'wanted': 50825,
#  'start': 44817,
#  '15': 440,
#  'got': 21282,
#  'low': 29195,
#  'didn': 14944,
#  'my': 32338,
#  'number': 33641,
#  'going': 21137,
#  'brain': 8582,
#  'fart': 18622,
#  'middle': 31059,
#  'order': 34379,
#  'signing': 43241,
#  'leaving': 28224,
#  'pence': 35617,
#  'frantically': 19875,
#  'cover': 12800,
#  'video': 50305,
#  'unwell': 49629,
#  'beleaguered': 7234,
#  'vaguely': 49944,
#  'irritated': 25407,
#  'distracted': 15517,
#  'what': 51263,
#  'meant': 30556,
#  'routine': 40996,
#  'remarks': 39644,
#  'few': 18943,
#  'words': 51828,
#  'hastily': 22398,
#  'room': 40872,
#  'forgot': 19681,
#  'whole': 51398,
#  'reason': 38924,
#  'first': 19170,
#  'sign': 43221,
#  'realizing': 38883,
#  'mistake': 31447,
#  'scrambles': 42028,
#  'stop': 45187,
#  'document': 15697,
#  'orders': 34383,
#  'folder': 19522,
#  'desk': 14661,
#  'outside': 34643,
#  'go': 21089,
#  'viral': 50420,
#  'bit': 7770,
#  'player': 36402,
#  'latest': 27999,
#  'camera': 9582,
#  'screw': 42068,
#  'awkwardly': 6375,
#  'saunters': 41677,
#  'grabs': 21351,
#  'rushes': 41185,
#  'ceremony': 10231,
#  'having': 22442,
#  'signed': 43233,
#  'pic': 36094,
#  'com': 11563,
#  'v0sjanotte': 49896,
#  'politico': 36636,
#  'march': 29910,
#  '31': 2448,
#  '2017trump': 1911,
#  'appeared': 5484,
#  'reluctant': 39624,
#  'come': 11584,
#  'back': 6487,
#  'into': 25170,
#  'pretty': 37273,
#  'obvious': 33894,
#  'why': 51423,
#  'mistakenly': 31449,
#  'left': 28273,
#  'reporter': 39837,
#  'questions': 38288,
#  'baffling': 6582,
#  'flynn': 19476,
#  'morning': 31871,
#  'immunity': 24135,
#  'witch': 51665,
#  'hunt': 23658,
#  'excuse': 18036,
#  'big': 7610,
#  'loss': 29132,
#  'media': 30597,
#  'dems': 14390,
#  'proportion': 37641,
#  'realdonaldtrump': 38856,
#  '2017it': 1548,
#  'understandable': 49108,
#  'explain': 18179,
#  'tweet': 48590,
#  'lead': 28162,
#  'eventual': 17880,
#  'downfall': 15964,
#  'york': 52410,
#  'times': 47418,
#  'points': 36569,
#  'doj': 15742,
#  'give': 20938,
#  'mean': 30542,
#  'likely': 28668,
#  'bigger': 7612,
#  'fish': 19182,
#  'fry': 20086,
#  'granted': 21435,
#  'congress': 12095,
#  'prosecutors': 37679,
#  'persuaded': 35851,
#  'mr': 32049,
#  'criminal': 13025,
#  'case': 9935,
#  'important': 24241,
#  'alleged': 4695,
#  'wrongdoing': 51984,
#  'may': 30318,
#  'overriding': 34765,
#  'objective': 33821,
#  'must': 32296,
#  'learning': 28210,
#  'anyone': 5402,
#  'united': 49340,
#  'states': 44852,
#  'collaborated': 11474,
#  'russians': 41200,
#  'knew': 27333,
#  'might': 31088,
#  'person': 35825,
#  'working': 51838,
#  'directly': 15111,
#  'above': 3653,
#  'spring': 44564,
#  'breakers': 8673,
#  'chant': 10358,
#  'mexico': 30962,
#  'vacationing': 49922,
#  'cancun': 9636,
#  'break': 8668,
#  'chants': 10363,
#  'earlier': 16504,
#  'month': 31783,
#  'though': 47239,
#  'complaints': 11793,
#  'refused': 39360,
#  'atlanta': 6074,
#  'journal': 26333,
#  'constitution': 12234,
#  'mexican': 30959,
#  'newspaper': 32960,
#  'yucatan': 52471,
#  'blasted': 7894,
#  'editorial': 16669,
#  'students': 45431,
#  'behavior': 7195,
#  'ship': 42902,
#  'unacceptable': 48894,
#  'paper': 35102,
#  'isolated': 25458,
#  'incident': 24396,
#  'young': 52425,
#  'noted': 33466,
#  'other': 34521,
#  'acts': 3925,
#  'xenophobia': 52104,
#  'discrimination': 15261,
#  'mexicans': 30961,
#  'within': 51686,
#  'days': 13797,
#  'many': 29876,
#  'offensive': 33987,
#  'rude': 41096,
#  'haughty': 22424,
#  'towards': 47817,
#  'witnesses': 51695,
#  'grew': 21557,
#  'increasingly': 24465,
#  'louder': 29146,
#  'face': 18372,
#  'stupidity': 45466,
#  'know': 27357,
#  'react': 38806,
#  'woman': 51764,
#  'boat': 8135,
#  'her': 22782,
#  'husband': 23703,
#  'witnessed': 51694,
#  'facebook': 18373,
#  'stunned': 45456,
#  'implausible': 24210,
#  'always': 4882,
#  'tolerant': 47606,
#  'countries': 12751,
#  'world': 51852,
#  'human': 23599,
#  'ignorance': 23973,
#  'characteristic': 10377,
#  'small': 43747,
#  'anaximandro': 5115,
#  'amable': 4894,
#  'cannot': 9672,
#  'discourse': 15240,
#  'incites': 24408,
#  'hatred': 22418,
#  'adds': 3999,
#  'situation': 43419,
#  'growing': 21683,
#  'tourism': 47800,
#  'sector': 42230,
#  'campaign': 9596,
#  'trail': 47916,
#  'crowd': 13124,
#  'supporters': 45825,
#  'routinely': 40997,
#  'great': 21492,
#  'nobody': 33285,
#  'builds': 9119,
#  'walls': 50790,
#  'better': 7507,
#  'than': 46949,
#  'southern': 44196,
#  'pay': 35434,
#  'now': 33537,
#  'paying': 35446,
#  'taxpayers': 46564,
#  'hey': 22874,
#  'guys': 21895,
#  'quit': 38320,
#  'embarrassing': 17027,
#  'rest': 40063,
#  'thanks': 46956,
#  'screen': 42056,
#  'capture': 9747,
#  'wtf': 52008,
#  'already': 4807,
#  '2020': 2009,
#  'details': 14712,
#  'running': 41164,
#  'set': 42539,
#  '2016': 861,
#  'using': 49803,
#  'funnel': 20204,
#  'money': 31719,
#  'wallet': 50784,
#  'businesses': 9286,
#  'because': 7115,
#  'patronize': 35369,
#  'anybody': 5400,
#  'else': 16984,
#  'them': 47051,
#  'donations': 15809,
#  'yourself': 52439,
#  'thus': 47324,
#  'amount': 5032,
#  'totals': 47774,
#  '500': 2807,
#  '000': 1,
#  '274': 2179,
#  'alone': 4789,
#  'gone': 21190,
#  'tower': 47820,
#  '58': 2898,
#  'plus': 36499,
#  'international': 25101,
#  'golf': 21171,
#  'club': 11234,
#  'florida': 19420,
#  'nearly': 32709,
#  '14': 413,
#  'las': 27964,
#  'hotel': 23435,
#  'various': 50057,
#  'properties': 37632,
#  'requires': 39916,
#  'candidate': 9643,
#  'uses': 49795,
#  'business': 9285,
#  'purposes': 38002,
#  'reimburse': 39476,
#  'market': 30019,
#  'value': 49992,
#  'goods': 21215,
#  'services': 42527,
#  'used': 49785,
#  'generally': 20629,
#  'winds': 51568,
#  'total': 47765,
#  'expenditures': 18154,
#  'june': 26488,
#  'million': 31193,
#  '10': 251,
#  'nov': 33520,
#  'part': 35225,
#  'forms': 19703,
#  'loophole': 29084,
#  'problem': 37426,
#  'advantage': 4141,
#  'fullest': 20156,
#  'extent': 18254,
#  'obama': 33787,
#  'stopped': 45198,
#  'fundraising': 20195,
#  'awhile': 6371,
#  'following': 19535,
#  '2008': 811,
#  'elected': 16861,
#  'rnc': 40636,
#  've': 50097,
#  'raised': 38518,
#  '42': 2647,
#  'together': 47591,
#  'refusal': 39357,
#  'divest': 15580,
#  'means': 30555,
#  'easily': 16538,
#  'speak': 44297,
#  'given': 20942,
#  'probably': 37418,
#  'transparent': 48011,
#  'long': 29046,
#  'way': 50981,
#  'trust': 48400,
#  'pockets': 36535,
#  'master': 30180,
#  'exploiting': 18198,
#  'loopholes': 29085,
#  'nothing': 33473,
#  'illegal': 24026,
#  'shut': 43135,
#  'ethical': 17770,
#  'fact': 18404,
#  'busy': 9308,
#  'funneling': 20206,
#  'stack': 44696,
#  'items': 25504,
#  'illustrating': 24055,
#  'unethical': 49195,
#  'alex': 4600,
#  'wong': 51790,
#  'getty': 20781,
#  'images': 24068,
#  'senator': 42377,
#  'warren': 50880,
#  'hits': 23073,
#  'effort': 16740,
#  'politicize': 36631,
#  'consumer': 12273,
#  'elizabeth': 16949,
#  'aim': 4424,
#  'chief': 10610,
#  'mick': 31032,
#  'mulvaney': 32213,
#  'fill': 19041,
#  'ranks': 38640,
#  'financial': 19079,
#  'watchdog': 50928,
#  'allies': 4725,
#  'letters': 28440,
#  'seen': 42281,
#  'salvo': 41481,
#  'broader': 8890,
#  'battle': 6979,
#  'run': 41155,
#  'appointed': 5525,
#  'acting': 3902,
#  'cfpb': 10260,
#  'decision': 13989,
#  'legally': 28292,
#  'challenged': 10316,
#  'leandra': 28190,
#  'english': 17304,
#  'she': 42782,
#  'rightful': 40494,
#  'interim': 25080,
#  'planned': 36354,
#  'several': 42573,
#  'appointees': 5527,
#  'overhaul': 34715,
#  'warned': 50863,
#  'pair': 34983,
#  'sent': 42437,
#  'personnel': 35841,
#  'management': 29752,
#  'opm': 34292,
#  'oversees': 34779,
#  'hiring': 23036,
#  'inappropriate': 24338,
#  ...}

# %% [markdown]
# `Bi-gram`

# %%
vectorizer2 = CountVectorizer(ngram_range=(2, 2))

# %%
vectorizer2.fit(train_text)
# Out:
# CountVectorizer(ngram_range=(2, 2))

# %%
vectorizer2.vocabulary_
# Out:
# {'as new': 79897,
#  'new fiscal': 497751,
#  'fiscal year': 284202,
#  'year dawns': 856322,
#  'dawns hope': 206498,
#  'hope for': 357122,
#  'for illinois': 290273,
#  'illinois budget': 367074,
#  'budget dims': 128443,
#  'dims chicago': 224989,
#  'chicago reuters': 154246,
#  'reuters risking': 633541,
#  'risking historic': 638094,
#  'historic drop': 353965,
#  'drop to': 239263,
#  'to junk': 767678,
#  'junk bond': 412695,
#  'bond status': 120336,
#  'status illinois': 701255,
#  'illinois began': 367070,
#  'began its': 106229,
#  'its third': 404274,
#  'third straight': 754839,
#  'straight fiscal': 705845,
#  'year without': 856952,
#  'without budget': 847359,
#  'budget on': 128559,
#  'on saturday': 529671,
#  'saturday as': 651048,
#  'as political': 80136,
#  'political maneuvering': 572202,
#  'maneuvering dimmed': 455774,
#  'dimmed hopes': 224956,
#  'hopes for': 357388,
#  'for bipartisan': 288911,
#  'bipartisan spending': 115823,
#  'spending and': 692360,
#  'and revenue': 61448,
#  'revenue package': 634125,
#  'package anytime': 549280,
#  'anytime soon': 68960,
#  'soon while': 688787,
#  'while the': 836055,
#  'the house': 740318,
#  'house scheduled': 360070,
#  'scheduled session': 654699,
#  'session on': 667154,
#  'on sunday': 529924,
#  'sunday to': 713372,
#  'to take': 770370,
#  'take up': 720219,
#  'up revenue': 800371,
#  'package the': 549364,
#  'the senate': 743953,
#  'senate is': 662812,
#  'is not': 396154,
#  'not slated': 506766,
#  'slated to': 681451,
#  'to return': 769502,
#  'return until': 632639,
#  'until monday': 799052,
#  'monday the': 478743,
#  'the nation': 741905,
#  'nation fifth': 491523,
#  'fifth largest': 279283,
#  'largest state': 425073,
#  'state has': 698566,
#  'has lacked': 332736,
#  'lacked full': 423076,
#  'full operating': 303377,
#  'operating budget': 534374,
#  'budget since': 128639,
#  'since july': 678840,
#  'july 2015': 411995,
#  '2015 and': 6722,
#  'and is': 58811,
#  'is under': 397572,
#  'under warning': 794508,
#  'warning from': 817214,
#  'from that': 302050,
#  'that it': 733050,
#  'it will': 402711,
#  'will drop': 840628,
#  'drop illinois': 239221,
#  'illinois creditworthiness': 367088,
#  'creditworthiness to': 198106,
#  'to the': 770473,
#  'the lowest': 741297,
#  'lowest of': 448783,
#  'of any': 515246,
#  'any state': 68155,
#  'state in': 698604,
#  'in history': 372930,
#  'history if': 354215,
#  'if it': 365753,
#  'it fails': 400921,
#  'fails to': 271494,
#  'to pass': 768661,
#  'pass fiscal': 554578,
#  'fiscal 2018': 284131,
#  '2018 budget': 11539,
#  'budget that': 128658,
#  'that starts': 734981,
#  'starts to': 698108,
#  'to address': 764675,
#  'address chronic': 28996,
#  'chronic structural': 157302,
#  'structural deficit': 708243,
#  'deficit talks': 212914,
#  'talks between': 721316,
#  'between democrats': 111652,
#  'democrats who': 216445,
#  'who control': 837193,
#  'control the': 187015,
#  'the illinois': 740427,
#  'illinois house': 367114,
#  'house and': 359225,
#  'and republicans': 61336,
#  'republicans had': 626881,
#  'had shown': 327396,
#  'shown signs': 675174,
#  'signs of': 677370,
#  'of progress': 519951,
#  'progress as': 589963,
#  'as both': 78310,
#  'both sides': 122426,
#  'sides rallied': 676316,
#  'rallied behind': 604058,
#  'behind 36': 107104,
#  '36 billion': 15301,
#  'billion spending': 115094,
#  'spending blueprint': 692377,
#  'blueprint on': 118858,
#  'on friday': 528344,
#  'friday and': 298684,
#  'and were': 63569,
#  'were poised': 829760,
#  'poised to': 570578,
#  'to build': 765287,
#  'build on': 128940,
#  'on that': 530009,
#  'that positive': 734071,
#  'positive movement': 575132,
#  'movement in': 485483,
#  'in rare': 374174,
#  'rare fourth': 605409,
#  'fourth of': 296328,
#  'of july': 518407,
#  'july holiday': 412174,
#  'holiday weekend': 355705,
#  'weekend legislative': 827051,
#  'legislative session': 433958,
#  'session instead': 667135,
#  'instead tensions': 385180,
#  'tensions broke': 726650,
#  'broke out': 127048,
#  'out on': 543952,
#  'on the': 530010,
#  'house floor': 359557,
#  'floor between': 286005,
#  'between house': 111729,
#  'house republican': 360021,
#  'republican leader': 626121,
#  'leader jim': 429751,
#  'jim durkin': 407781,
#  'durkin and': 241071,
#  'and democratic': 56507,
#  'democratic house': 215619,
#  'house speaker': 360138,
#  'speaker michael': 690669,
#  'michael madigan': 470935,
#  'madigan who': 450972,
#  'who initially': 837582,
#  'initially informed': 383328,
#  'informed the': 382700,
#  'the legislative': 741098,
#  'legislative chamber': 433872,
#  'chamber that': 150827,
#  'that no': 733697,
#  'no budget': 501432,
#  'budget votes': 128681,
#  'votes would': 813880,
#  'would be': 852628,
#  'be taken': 100937,
#  'taken on': 720397,
#  'sunday saying': 713327,
#  'saying we': 652754,
#  'we ll': 824324,
#  'll gavel': 443871,
#  'gavel out': 307729,
#  'out and': 543432,
#  'and return': 61436,
#  'return at': 632570,
#  'at some': 85956,
#  'some point': 686775,
#  'point sunday': 570320,
#  'to me': 768095,
#  'me does': 463578,
#  'does not': 233014,
#  'not send': 506695,
#  'send message': 663894,
#  'message to': 469662,
#  'to illinoisans': 767353,
#  'illinoisans that': 367195,
#  'that we': 735600,
#  'we re': 824434,
#  're prepared': 607270,
#  'prepared to': 580138,
#  'to bring': 765257,
#  'bring this': 126137,
#  'this to': 756838,
#  'to resolution': 769456,
#  'resolution any': 629703,
#  'any time': 68226,
#  'time soon': 763098,
#  'soon said': 688750,
#  'said durkin': 646859,
#  'durkin the': 241076,
#  'the republican': 743467,
#  'republican party': 626258,
#  'party legislative': 554161,
#  'legislative proxy': 433945,
#  'proxy for': 595716,
#  'for governor': 290068,
#  'governor bruce': 319042,
#  'bruce rauner': 127723,
#  'rauner who': 606536,
#  'who has': 837515,
#  'has stayed': 333409,
#  'stayed on': 701526,
#  'the sidelines': 744126,
#  'sidelines of': 676236,
#  'of recent': 520161,
#  'recent budget': 611918,
#  'budget negotiations': 128544,
#  'negotiations madigan': 495558,
#  'madigan walked': 450971,
#  'walked off': 815053,
#  'off the': 522513,
#  'the floor': 739502,
#  'floor short': 286083,
#  'short time': 673319,
#  'time later': 762814,
#  'later to': 426025,
#  'the shout': 744107,
#  'shout of': 674207,
#  'of speaker': 520908,
#  'speaker junk': 690658,
#  'junk from': 412699,
#  'from state': 301935,
#  'state representative': 698908,
#  'representative grant': 624899,
#  'grant wehrli': 320282,
#  'wehrli suburban': 827398,
#  'suburban chicago': 710441,
#  'chicago republican': 154245,
#  'republican by': 625807,
#  'by late': 135500,
#  'late afternoon': 425603,
#  'afternoon madigan': 35132,
#  'madigan reversed': 450967,
#  'reversed course': 634313,
#  'course and': 194540,
#  'and said': 61619,
#  'said there': 648393,
#  'there indeed': 750872,
#  'indeed would': 379806,
#  'be vote': 101241,
#  'vote on': 812923,
#  'on tax': 529969,
#  'tax increase': 723268,
#  'increase package': 378927,
#  'package sunday': 549362,
#  'sunday neglecting': 713277,
#  'neglecting any': 495332,
#  'any mention': 67800,
#  'mention of': 468783,
#  'of accompanying': 515000,
#  'accompanying votes': 23276,
#  'votes on': 813783,
#  'on local': 528855,
#  'local property': 444704,
#  'property tax': 592080,
#  'tax freeze': 723231,
#  'freeze or': 298281,
#  'or workers': 538368,
#  'workers compensation': 850687,
#  'compensation reforms': 175485,
#  'reforms that': 615478,
#  'that are': 730922,
#  'are two': 75177,
#  'two of': 791621,
#  'of rauner': 520130,
#  'rauner key': 606507,
#  'key demands': 417552,
#  'demands under': 214939,
#  'under negotiation': 794357,
#  'negotiation in': 495494,
#  'in statement': 374752,
#  'statement madigan': 699543,
#  'madigan said': 450968,
#  'said he': 647152,
#  'he was': 339968,
#  'was encouraged': 818686,
#  'encouraged by': 251660,
#  'by the': 136623,
#  'the progress': 742988,
#  'progress in': 589985,
#  'in talks': 374896,
#  'talks with': 721466,
#  'with durkin': 844412,
#  'and vowed': 63446,
#  'vowed to': 814090,
#  'to vote': 770870,
#  'vote sunday': 813021,
#  'sunday on': 713289,
#  'on revenue': 529597,
#  'package modeled': 549336,
#  'modeled on': 477434,
#  'the bill': 736928,
#  'bill supported': 114689,
#  'supported by': 714345,
#  'the governor': 739873,
#  'governor and': 319011,
#  'and house': 58327,
#  'and senate': 61798,
#  'senate republicans': 662977,
#  'republicans durkin': 626794,
#  'durkin made': 241072,
#  'made clear': 450423,
#  'clear in': 161156,
#  'in his': 372926,
#  'his own': 352620,
#  'own statement': 548567,
#  'statement that': 699736,
#  'that there': 735239,
#  'there is': 750880,
#  'is no': 396133,
#  'no agreement': 501330,
#  'agreement on': 38645,
#  'on comprehensive': 527797,
#  'comprehensive budget': 177003,
#  'budget package': 128568,
#  'package that': 549363,
#  'that includes': 732918,
#  'includes reforms': 377386,
#  'reforms and': 615432,
#  'revenue contradicting': 634078,
#  'contradicting madigan': 186537,
#  'madigan and': 450956,
#  'and painting': 60258,
#  'painting dim': 550312,
#  'dim outlook': 224881,
#  'outlook for': 544816,
#  'bipartisan consensus': 115741,
#  'consensus on': 181748,
#  'sunday this': 713368,
#  'this impasse': 755860,
#  'impasse can': 369124,
#  'can only': 141171,
#  'only be': 532435,
#  'be resolved': 100502,
#  'resolved in': 629944,
#  'in negotiated': 373635,
#  'negotiated manner': 495414,
#  'manner durkin': 456073,
#  'durkin said': 241074,
#  'said it': 647286,
#  'it is': 401350,
#  'is our': 396225,
#  'our hope': 542594,
#  'hope that': 357181,
#  'that democrats': 731885,
#  'democrats will': 216449,
#  'will remain': 841076,
#  'remain at': 619902,
#  'at the': 86058,
#  'the negotiating': 741952,
#  'negotiating table': 495475,
#  'schumer says': 655615,
#  'says budget': 652849,
#  'budget deal': 128429,
#  'deal doable': 208054,
#  'doable if': 232211,
#  'if trump': 366106,
#  'trump stays': 785626,
#  'stays out': 701581,
#  'out of': 543946,
#  'of it': 518328,
#  'it washington': 402672,
#  'washington reuters': 821479,
#  'reuters senate': 633570,
#  'senate democratic': 662674,
#  'democratic leader': 215636,
#  'leader chuck': 429663,
#  'chuck schumer': 157363,
#  'schumer said': 655614,
#  'said on': 647788,
#  'sunday he': 713226,
#  'he believes': 337897,
#  'believes lawmakers': 109118,
#  'lawmakers could': 428163,
#  'could reach': 191714,
#  'reach short': 607635,
#  'short term': 673309,
#  'term budget': 726836,
#  'deal by': 208010,
#  'by friday': 135099,
#  'friday if': 298860,
#  'if president': 365936,
#  'president donald': 581277,
#  'donald trump': 235085,
#  'trump did': 782899,
#  'did not': 223235,
#  'not meddle': 506069,
#  'meddle in': 465265,
#  'in their': 374967,
#  'their talks': 748082,
#  'with poison': 845805,
#  'poison pill': 570590,
#  'pill demands': 565823,
#  'demands like': 214903,
#  'like funding': 439207,
#  'funding for': 304266,
#  'for border': 288956,
#  'border wall': 121376,
#  'wall am': 815165,
#  'am hopeful': 48554,
#  'hopeful that': 357281,
#  'we can': 824038,
#  'can get': 140999,
#  'get budget': 309950,
#  'budget done': 128450,
#  'done schumer': 235547,
#  'said at': 646371,
#  'at news': 85571,
#  'news conference': 498745,
#  'conference the': 179107,
#  'the only': 742218,
#  'only fly': 532723,
#  'fly in': 286620,
#  'in the': 374964,
#  'the ointment': 742193,
#  'ointment is': 526089,
#  'is that': 397390,
#  'that the': 735233,
#  'the president': 742886,
#  'president is': 581531,
#  'is being': 394076,
#  'being little': 108029,
#  'little heavy': 443001,
#  'heavy handed': 342303,
#  'handed and': 329001,
#  'and mixing': 59719,
#  'mixing in': 476801,
#  'in and': 371349,
#  'and asking': 54806,
#  'asking for': 82228,
#  'for things': 292177,
#  'things such': 754033,
#  'such as': 710952,
#  'as the': 80908,
#  'the border': 737069,
#  'wall so': 815375,
#  'so we': 684710,
#  'we ask': 823994,
#  'ask him': 81724,
#  'him to': 349475,
#  'to let': 767865,
#  'let us': 435441,
#  'us do': 801980,
#  'do our': 232004,
#  'our work': 543224,
#  'work not': 850359,
#  'not throw': 506973,
#  'throw in': 760617,
#  'in some': 374675,
#  'some last': 686555,
#  'last minute': 425357,
#  'minute poison': 475099,
#  'poison pills': 570591,
#  'pills that': 565856,
#  'that could': 731700,
#  'could undo': 191914,
#  'undo it': 795307,
#  'it and': 400170,
#  'and we': 63529,
#  'we could': 824080,
#  'could get': 191483,
#  'get this': 310442,
#  'this done': 755488,
#  'nra calls': 509710,
#  'calls for': 138970,
#  'for more': 290872,
#  'more regulation': 482110,
#  'regulation after': 617088,
#  'after vegas': 35003,
#  'vegas shooting': 805940,
#  'shooting washington': 673019,
#  'reuters the': 633637,
#  'the national': 741906,
#  'national rifle': 492094,
#  'rifle association': 636377,
#  'association said': 83962,
#  'on thursday': 530040,
#  'thursday devices': 761025,
#  'devices that': 222092,
#  'that allow': 730821,
#  'allow semi': 44243,
#  'semi automatic': 662288,
#  'automatic rifles': 89849,
#  'rifles to': 636402,
#  'to function': 766924,
#  'function like': 303766,
#  'like fully': 439206,
#  'fully automatic': 303523,
#  'automatic ones': 89845,
#  'ones need': 531904,
#  'need tougher': 494743,
#  'tougher regulation': 775306,
#  'regulation and': 617092,
#  'and it': 58833,
#  'it called': 400402,
#  'called on': 138486,
#  'on regulators': 529525,
#  'regulators to': 617438,
#  'to determine': 766124,
#  'determine whether': 221335,
#  'whether the': 833929,
#  'the bump': 737227,
#  'bump stock': 129743,
#  'stock devices': 704053,
#  'devices comply': 222067,
#  'comply with': 176906,
#  'with federal': 844569,
#  'federal law': 276956,
#  'law the': 427815,
#  'association is': 83934,
#  'is calling': 394261,
#  'calling on': 138858,
#  'the bureau': 737236,
#  'bureau of': 129950,
#  'of alcohol': 515142,
#  'alcohol tobacco': 41128,
#  'tobacco firearms': 771135,
#  'firearms and': 282446,
#  'and explosives': 57376,
#  'explosives to': 267484,
#  'to immediately': 767363,
#  'immediately review': 368133,
#  'review whether': 634605,
#  'whether these': 833932,
#  'these devices': 751600,
#  'the powerful': 742821,
#  'powerful gun': 578048,
#  'gun lobby': 324920,
#  'lobby group': 444330,
#  'group said': 322866,
#  'said in': 647227,
#  'statement the': 699737,
#  'the nra': 742086,
#  'nra believes': 509707,
#  'believes that': 109154,
#  'that devices': 731939,
#  'devices designed': 222069,
#  'designed to': 219739,
#  'to allow': 764769,
#  'rifles should': 636400,
#  'should be': 673647,
#  'be subject': 100871,
#  'subject to': 709670,
#  'to additional': 764674,
#  'additional regulations': 28880,
#  'regulations it': 617266,
#  'it said': 402141,
#  'white house': 836532,
#  'house says': 360064,
#  'says tillerson': 653310,
#  'tillerson to': 762295,
#  'to remain': 769369,
#  'remain as': 619899,
#  'as secretary': 80570,
#  'secretary of': 658671,
#  'of state': 520984,
#  'state washington': 699108,
#  'reuters rex': 633537,
#  'rex tillerson': 635187,
#  'tillerson will': 762324,
#  'state the': 699038,
#  'the white': 745824,
#  'house spokeswoman': 360152,
#  'spokeswoman said': 694134,
#  'thursday amid': 760920,
#  'amid reports': 51531,
#  'reports tillerson': 624676,
#  'will be': 840447,
#  'be removed': 100455,
#  'removed in': 621079,
#  'in favor': 372560,
#  'favor of': 275095,
#  'of mike': 518993,
#  'mike pompeo': 472024,
#  'pompeo who': 573612,
#  'who is': 837606,
#  'is currently': 394619,
#  'currently cia': 202123,
#  'cia director': 157638,
#  'director when': 226309,
#  'when the': 832983,
#  'president loses': 581637,
#  'loses confidence': 447086,
#  'confidence in': 179223,
#  'in someone': 374677,
#  'someone they': 687648,
#  'they will': 753413,
#  'will no': 840920,
#  'no longer': 501956,
#  'longer serve': 445908,
#  'serve here': 666307,
#  'here white': 346028,
#  'spokeswoman sarah': 694136,
#  'sarah sanders': 650646,
#  'sanders said': 650298,
#  'said when': 648596,
#  'when asked': 832181,
#  'asked about': 81812,
#  'about reports': 21038,
#  'reports of': 624596,
#  'of staff': 520960,
#  'staff shake': 695789,
#  'shake up': 669503,
#  'scientists scramble': 655960,
#  'scramble to': 656497,
#  'to copy': 765793,
#  'copy climate': 189025,
#  'climate data': 162149,
#  'data before': 205553,
#  'before trump': 106039,
#  'trump can': 782352,
#  'can make': 141130,
#  'make it': 453153,
#  'it all': 400141,
#  'all disappear': 42086,
#  'disappear donald': 226701,
#  'trump isn': 783920,
#  'isn exactly': 398546,
#  'exactly stickler': 263356,
#  'stickler for': 702994,
#  'for facts': 289832,
#  'facts and': 270914,
#  'and he': 58153,
#  'he has': 338653,
#  'has made': 332811,
#  'made it': 450588,
#  'it clear': 400472,
#  'clear that': 161282,
#  'that he': 732745,
#  'he is': 338807,
#  'not convinced': 505143,
#  'convinced that': 187956,
#  'that climate': 731486,
#  'climate change': 162138,
#  'change is': 151259,
#  'is real': 396646,
#  'real heck': 608680,
#  'heck he': 342361,
#  'he doesn': 338345,
#  'doesn necessarily': 233305,
#  'necessarily even': 494290,
#  'even believe': 259763,
#  'believe that': 108943,
#  'that science': 734667,
#  'science is': 655777,
#  'real maybe': 608736,
#  'maybe global': 461826,
#  'global warming': 313646,
#  'warming is': 816971,
#  'is just': 395735,
#  'just chinese': 413110,
#  'chinese hoax': 155957,
#  'hoax right': 354866,
#  'right and': 636537,
#  'and the': 62766,
#  'the people': 742544,
#  'people he': 559695,
#  'has picked': 332992,
#  'picked for': 565328,
#  'for his': 290196,
#  'his cabinet': 350883,
#  'cabinet are': 137063,
#  'are far': 73595,
#  'far from': 273750,
#  'from environmentally': 300536,
#  'environmentally friendly': 255793,
#  'friendly well': 299341,
#  'well scientists': 828298,
#  'scientists have': 655942,
#  'have taken': 336592,
#  'taken notice': 720388,
#  'notice and': 507746,
#  'and are': 54757,
#  'are taking': 75041,
#  'taking action': 720650,
#  'action they': 25960,
#  'they are': 752322,
#  'are scrambling': 74783,
#  'scrambling to': 656513,
#  'trump administration': 781826,
#  'administration has': 29948,
#  'has the': 333503,
#  'the chance': 737486,
#  'chance to': 151039,
#  'to make': 768003,
#  'all just': 42386,
#  'just disappear': 413243,
#  'disappear the': 226715,
#  'the washington': 745730,
#  'washington post': 821429,
#  'post reports': 576168,
#  'reports the': 624668,
#  'the efforts': 738912,
#  'efforts include': 245387,
#  'include guerrilla': 376733,
#  'guerrilla archiving': 324248,
#  'archiving event': 72696,
#  'event in': 260911,
#  'in toronto': 375028,
#  'toronto where': 774405,
#  'where experts': 833272,
#  'experts will': 266871,
#  'will copy': 840555,
#  'copy irreplaceable': 189029,
#  'irreplaceable public': 393535,
#  'public data': 596166,
#  'data meetings': 205638,
#  'meetings at': 466985,
#  'the university': 745404,
#  'university of': 797349,
#  'of pennsylvania': 519658,
#  'pennsylvania focused': 558899,
#  'focused on': 287207,
#  'on how': 528540,
#  'how to': 361225,
#  'to download': 766308,
#  'download as': 237265,
#  'as much': 79838,
#  'much federal': 486498,
#  'federal data': 276864,
#  'data as': 205547,
#  'as possible': 80157,
#  'possible in': 575476,
#  'the coming': 737771,
#  'coming weeks': 171629,
#  'weeks and': 827206,
#  'and collaboration': 55788,
#  'collaboration of': 167130,
#  'of scientists': 520560,
#  'scientists and': 655911,
#  'and database': 56349,
#  'database experts': 205740,
#  'experts who': 266869,
#  'who are': 836984,
#  'are compiling': 73168,
#  'compiling an': 175761,
#  'an online': 53316,
#  'online site': 532242,
#  'site to': 679842,
#  'to harbor': 767148,
#  'harbor scientific': 330768,
#  'scientific information': 655856,
#  'information nick': 382490,
#  'nick santos': 500249,
#  'santos an': 650581,
#  'an environmental': 52737,
#  'environmental researcher': 255752,
#  'researcher at': 628725,
#  'of california': 515822,
#  'california at': 137527,
#  'at davis': 84915,
#  'davis is': 206442,
#  'is one': 396206,
#  'one of': 531324,
#  'of the': 521313,
#  'the scientists': 743870,
#  'scientists who': 655974,
#  'not risking': 506622,
#  'risking it': 638095,
#  'it over': 401755,
#  'over the': 546347,
#  'the weekend': 745774,
#  'weekend he': 827031,
#  'he started': 339679,
#  'started copying': 697813,
#  'copying government': 189043,
#  'government climate': 318155,
#  'data onto': 205653,
#  'onto public': 533598,
#  'public server': 596464,
#  'server something': 666480,
#  'something that': 687998,
#  'that seemed': 734700,
#  'seemed little': 660884,
#  'little paranoid': 443098,
#  'paranoid to': 551869,
#  'me before': 463520,
#  'before all': 105486,
#  'all of': 42555,
#  'of sudden': 521110,
#  'sudden seems': 711714,
#  'seems potentially': 661096,
#  'potentially realistic': 577163,
#  'realistic or': 609588,
#  'or at': 536156,
#  'at least': 85396,
#  'least something': 431720,
#  'something you': 688049,
#  'you want': 860191,
#  'want to': 816041,
#  'to hedge': 767201,
#  'hedge against': 342406,
#  'against santos': 36487,
#  'santos said': 650585,
#  'said doing': 646828,
#  'doing this': 233763,
#  'this can': 755205,
#  'be good': 99369,
#  'good thing': 316010,
#  'thing hopefully': 753622,
#  'hopefully they': 357353,
#  'they leave': 752852,
#  'leave everything': 431826,
#  'everything in': 262610,
#  'in place': 373928,
#  'place but': 566566,
#  'but if': 132433,
#  'if not': 365883,
#  'not we': 507170,
#  're planning': 607258,
#  'planning for': 567971,
#  'for that': 292164,
#  'that michael': 733512,
#  'michael halpern': 470914,
#  'halpern who': 328354,
#  'is the': 397391,
#  'the deputy': 738465,
#  'deputy director': 218897,
#  'director of': 226225,
#  'the center': 737440,
#  'center for': 148424,
#  'for science': 291758,
#  'science and': 655727,
#  'and democracy': 56505,
#  'democracy at': 215058,
#  'the advocacy': 736235,
#  'advocacy group': 32513,
#  'group union': 322951,
#  'union of': 796715,
#  'of concerned': 516231,
#  'concerned scientists': 177675,
#  'scientists said': 655958,
#  'in an': 371347,
#  'an email': 52665,
#  'email that': 249165,
#  'people trump': 560281,
#  'trump has': 783601,
#  'picked to': 565361,
#  'to head': 767182,
#  'head up': 340215,
#  'up government': 799958,
#  'government agencies': 318038,
#  'agencies so': 36954,
#  'so far': 684014,
#  'far have': 273760,
#  'have been': 334801,
#  'been band': 103541,
#  'band of': 94632,
#  'of climate': 516083,
#  'climate conspiracy': 162145,
#  'conspiracy theorists': 183696,
#  'theorists they': 750515,
#  'they have': 752752,
#  'been salivating': 104906,
#  'salivating at': 648976,
#  'the possibility': 742800,
#  'possibility of': 575292,
#  'of dismantling': 516809,
#  'dismantling federal': 229197,
#  'federal climate': 276839,
#  'climate research': 162208,
#  'research programs': 628672,
#  'programs for': 589837,
#  'for years': 292574,
#  'years it': 857243,
#  'it not': 401686,
#  'not unreasonable': 507086,
#  'unreasonable to': 798530,
#  'to think': 770486,
#  'think they': 754405,
#  'they would': 753427,
#  'would want': 853637,
#  'take down': 719911,
#  'down the': 237138,
#  'the very': 745570,
#  'very data': 806888,
#  'data that': 205701,
#  'that they': 735241,
#  'they dispute': 752579,
#  'dispute he': 229778,
#  'he wrote': 340052,
#  'wrote there': 855126,
#  'is fine': 395139,
#  'fine line': 281975,
#  'line between': 441365,
#  'between being': 111591,
#  'being paranoid': 108149,
#  'paranoid and': 551841,
#  'and being': 55057,
#  'being prepared': 108198,
#  'prepared and': 580096,
#  'and scientists': 61706,
#  'scientists are': 655912,
#  'are doing': 73406,
#  'doing their': 233757,
#  'their best': 746357,
#  'best to': 110922,
#  'to be': 765049,
#  'be prepared': 100220,
#  'prepared scientists': 580127,
#  'are right': 74731,
#  'right to': 636954,
#  'to preserve': 768920,
#  'preserve data': 580528,
#  'data and': 205546,
#  'and archive': 54754,
#  'archive websites': 72676,
#  'websites before': 825756,
#  'before those': 106019,
#  'those who': 758148,
#  'who want': 838317,
#  'to dismantle': 766217,
#  'dismantle federal': 229162,
#  'change research': 151356,
#  'programs storm': 589919,
#  'storm the': 705454,
#  'the castle': 737397,
#  'castle trump': 146325,
#  'has never': 332890,
#  'never said': 497155,
#  'he intends': 338781,
#  'intends to': 386892,
#  'to manipulate': 768024,
#  'manipulate scientific': 455952,
#  'scientific data': 655846,
#  'data but': 205561,
#  'but scientists': 133073,
#  'scientists located': 655947,
#  'located across': 444800,
#  'across the': 25271,
#  'the country': 738071,
#  'country aren': 193427,
#  'aren taking': 75802,
#  'taking chances': 720692,
#  'chances researchers': 151084,
#  'researchers at': 628733,
#  'pennsylvania are': 558869,
#  'are feverishly': 73614,
#  'feverishly trying': 278616,
#  'trying to': 787313,
#  'to figure': 766756,
#  'figure out': 279729,
#  'out the': 544206,
#  'the best': 736900,
#  'best ways': 110936,
#  'ways to': 823884,
#  'copy and': 189022,
#  'and preserve': 60688,
#  'preserve their': 580559,
#  'their data': 746677,
#  'data the': 205702,
#  'of toronto': 521403,
#  'toronto is': 774397,
#  'is holding': 395475,
#  'holding guerrilla': 355375,
#  'event this': 260998,
#  'this weekend': 756991,
#  'weekend to': 827101,
#  'to collect': 765589,
#  'collect vital': 167384,
#  'vital federal': 811959,
#  'federal environmental': 276899,
#  'environmental data': 255706,
#  'trump takes': 785780,
#  'takes office': 720578,
#  'office according': 523286,
#  'according to': 23549,
#  'to organizers': 768558,
#  'organizers the': 539827,
#  'the event': 739133,
#  'event is': 260918,
#  'is focused': 395173,
#  ...}

# %% [markdown]
# `trigram`

# %%
vectorizer3 = CountVectorizer(ngram_range=(3,3))

# %%
vectorizer3.fit(train_text)
# Out:
# CountVectorizer(ngram_range=(3, 3))

# %%
vectorizer3.vocabulary_
# Out:
# {'as new fiscal': 193186,
#  'new fiscal year': 1124423,
#  'fiscal year dawns': 614333,
#  'year dawns hope': 2077001,
#  'dawns hope for': 457183,
#  'hope for illinois': 801443,
#  'for illinois budget': 629166,
#  'illinois budget dims': 825607,
#  'budget dims chicago': 296256,
#  'dims chicago reuters': 495822,
#  'chicago reuters risking': 355428,
#  'reuters risking historic': 1445460,
#  'risking historic drop': 1455415,
#  'historic drop to': 796003,
#  'drop to junk': 526106,
#  'to junk bond': 1824887,
#  'junk bond status': 949864,
#  'bond status illinois': 283087,
#  'status illinois began': 1592060,
#  'illinois began its': 825601,
#  'began its third': 255859,
#  'its third straight': 932603,
#  'third straight fiscal': 1775048,
#  'straight fiscal year': 1600695,
#  'fiscal year without': 614376,
#  'year without budget': 2079122,
#  'without budget on': 2052996,
#  'budget on saturday': 296611,
#  'on saturday as': 1224127,
#  'saturday as political': 1486506,
#  'as political maneuvering': 193891,
#  'political maneuvering dimmed': 1321308,
#  'maneuvering dimmed hopes': 1038648,
#  'dimmed hopes for': 495781,
#  'hopes for bipartisan': 802188,
#  'for bipartisan spending': 624132,
#  'bipartisan spending and': 275522,
#  'spending and revenue': 1572533,
#  'and revenue package': 143602,
#  'revenue package anytime': 1446976,
#  'package anytime soon': 1274702,
#  'anytime soon while': 167173,
#  'soon while the': 1565306,
#  'while the house': 2016010,
#  'the house scheduled': 1705233,
#  'house scheduled session': 808482,
#  'scheduled session on': 1494977,
#  'session on sunday': 1521070,
#  'on sunday to': 1225151,
#  'sunday to take': 1613706,
#  'to take up': 1842092,
#  'take up revenue': 1627433,
#  'up revenue package': 1925013,
#  'revenue package the': 1446978,
#  'package the senate': 1274869,
#  'the senate is': 1733566,
#  'senate is not': 1511405,
#  'is not slated': 903184,
#  'not slated to': 1148071,
#  'slated to return': 1550335,
#  'to return until': 1836429,
#  'return until monday': 1443632,
#  'until monday the': 1921640,
#  'monday the nation': 1084634,
#  'the nation fifth': 1716536,
#  'nation fifth largest': 1111801,
#  'fifth largest state': 604148,
#  'largest state has': 974581,
#  'state has lacked': 1584283,
#  'has lacked full': 726272,
#  'lacked full operating': 971693,
#  'full operating budget': 664718,
#  'operating budget since': 1240518,
#  'budget since july': 296848,
#  'since july 2015': 1545585,
#  'july 2015 and': 947982,
#  '2015 and is': 11388,
#  'and is under': 132409,
#  'is under warning': 909947,
#  'under warning from': 1913613,
#  'warning from that': 1961107,
#  'from that it': 660754,
#  'that it will': 1661370,
#  'it will drop': 928891,
#  'will drop illinois': 2031698,
#  'drop illinois creditworthiness': 525970,
#  'illinois creditworthiness to': 825623,
#  'creditworthiness to the': 442405,
#  'to the lowest': 1843839,
#  'the lowest of': 1712045,
#  'lowest of any': 1025028,
#  'of any state': 1170081,
#  'any state in': 165083,
#  'state in history': 1584390,
#  'in history if': 842736,
#  'history if it': 796449,
#  'if it fails': 821683,
#  'it fails to': 919529,
#  'fails to pass': 588474,
#  'to pass fiscal': 1830820,
#  'pass fiscal 2018': 1284634,
#  'fiscal 2018 budget': 614147,
#  '2018 budget that': 19297,
#  'budget that starts': 296893,
#  'that starts to': 1668919,
#  'starts to address': 1583051,
#  'to address chronic': 1802861,
#  'address chronic structural': 54659,
#  'chronic structural deficit': 361376,
#  'structural deficit talks': 1604580,
#  'deficit talks between': 472096,
#  'talks between democrats': 1630421,
#  'between democrats who': 266644,
#  'democrats who control': 479286,
#  'who control the': 2020573,
#  'control the illinois': 418954,
#  'the illinois house': 1705661,
#  'illinois house and': 825669,
#  'house and republicans': 805493,
#  'and republicans had': 143244,
#  'republicans had shown': 1431782,
#  'had shown signs': 712741,
#  'shown signs of': 1539106,
#  'signs of progress': 1543096,
#  'of progress as': 1189941,
#  'progress as both': 1357772,
#  'as both sides': 188933,
#  'both sides rallied': 286586,
#  'sides rallied behind': 1541250,
#  'rallied behind 36': 1383908,
#  'behind 36 billion': 257589,
#  '36 billion spending': 25628,
#  'billion spending blueprint': 274212,
#  'spending blueprint on': 1572636,
#  'blueprint on friday': 280862,
#  'on friday and': 1218350,
#  'friday and were': 652501,
#  'and were poised': 154758,
#  'were poised to': 1997980,
#  'poised to build': 1317402,
#  'to build on': 1808711,
#  'build on that': 297369,
#  'on that positive': 1225593,
#  'that positive movement': 1665640,
#  'positive movement in': 1326925,
#  'movement in rare': 1099709,
#  'in rare fourth': 849181,
#  'rare fourth of': 1386420,
#  'fourth of july': 648128,
#  'of july holiday': 1183397,
#  'july holiday weekend': 948510,
#  'holiday weekend legislative': 799085,
#  'weekend legislative session': 1990983,
#  'legislative session instead': 994815,
#  'session instead tensions': 1521038,
#  'instead tensions broke': 874482,
#  'tensions broke out': 1642241,
#  'broke out on': 293959,
#  'out on the': 1263113,
#  'on the house': 1226305,
#  'the house floor': 1705108,
#  'house floor between': 806489,
#  'floor between house': 617430,
#  'between house republican': 266762,
#  'house republican leader': 808182,
#  'republican leader jim': 1428685,
#  'leader jim durkin': 985525,
#  'jim durkin and': 939328,
#  'durkin and democratic': 529756,
#  'and democratic house': 122242,
#  'democratic house speaker': 476552,
#  'house speaker michael': 808662,
#  'speaker michael madigan': 1569199,
#  'michael madigan who': 1069483,
#  'madigan who initially': 1029113,
#  'who initially informed': 2022327,
#  'initially informed the': 871207,
#  'informed the legislative': 870266,
#  'the legislative chamber': 1710947,
#  'legislative chamber that': 994611,
#  'chamber that no': 348979,
#  'that no budget': 1663911,
#  'no budget votes': 1133399,
#  'budget votes would': 296968,
#  'votes would be': 1953628,
#  'would be taken': 2066837,
#  'be taken on': 242091,
#  'taken on sunday': 1627872,
#  'on sunday saying': 1225118,
#  'sunday saying we': 1613547,
#  'saying we ll': 1491230,
#  'we ll gavel': 1983540,
#  'll gavel out': 1014571,
#  'gavel out and': 672227,
#  'out and return': 1261254,
#  'and return at': 143569,
#  'return at some': 1443436,
#  'at some point': 208613,
#  'some point sunday': 1560983,
#  'point sunday to': 1316612,
#  'sunday to me': 1613697,
#  'to me does': 1827716,
#  'me does not': 1053590,
#  'does not send': 511211,
#  'not send message': 1147890,
#  'send message to': 1514291,
#  'message to illinoisans': 1066973,
#  'to illinoisans that': 1823046,
#  'illinoisans that we': 825808,
#  'that we re': 1674149,
#  'we re prepared': 1984279,
#  're prepared to': 1390605,
#  'prepared to bring': 1335575,
#  'to bring this': 1808539,
#  'bring this to': 292578,
#  'this to resolution': 1782654,
#  'to resolution any': 1836087,
#  'resolution any time': 1437719,
#  'any time soon': 165258,
#  'time soon said': 1798528,
#  'soon said durkin': 1565216,
#  'said durkin the': 1474098,
#  'durkin the republican': 529764,
#  'the republican party': 1729698,
#  'republican party legislative': 1429326,
#  'party legislative proxy': 1283663,
#  'legislative proxy for': 994788,
#  'proxy for governor': 1368205,
#  'for governor bruce': 627782,
#  'governor bruce rauner': 696282,
#  'bruce rauner who': 295092,
#  'rauner who has': 1388777,
#  'who has stayed': 2021811,
#  'has stayed on': 729248,
#  'stayed on the': 1592620,
#  'on the sidelines': 1226913,
#  'the sidelines of': 1734613,
#  'sidelines of recent': 1541121,
#  'of recent budget': 1190678,
#  'recent budget negotiations': 1400516,
#  'budget negotiations madigan': 296509,
#  'negotiations madigan walked': 1120222,
#  'madigan walked off': 1029112,
#  'walked off the': 1955866,
#  'off the floor': 1205263,
#  'the floor short': 1700049,
#  'floor short time': 617557,
#  'short time later': 1534146,
#  'time later to': 1797877,
#  'later to the': 977541,
#  'to the shout': 1844402,
#  'the shout of': 1734447,
#  'shout of speaker': 1536998,
#  'of speaker junk': 1193501,
#  'speaker junk from': 1569183,
#  'junk from state': 949868,
#  'from state representative': 660471,
#  'state representative grant': 1585242,
#  'representative grant wehrli': 1425887,
#  'grant wehrli suburban': 698197,
#  'wehrli suburban chicago': 1991788,
#  'suburban chicago republican': 1608219,
#  'chicago republican by': 355408,
#  'republican by late': 1427640,
#  'by late afternoon': 313990,
#  'late afternoon madigan': 976636,
#  'afternoon madigan reversed': 68490,
#  'madigan reversed course': 1029101,
#  'reversed course and': 1447303,
#  'course and said': 435209,
#  'and said there': 144285,
#  'said there indeed': 1480351,
#  'there indeed would': 1759436,
#  'indeed would be': 864940,
#  'would be vote': 2066933,
#  'be vote on': 243444,
#  'vote on tax': 1950817,
#  'on tax increase': 1225334,
#  'tax increase package': 1634568,
#  'increase package sunday': 863626,
#  'package sunday neglecting': 1274845,
#  'sunday neglecting any': 1613446,
#  'neglecting any mention': 1119824,
#  'any mention of': 164070,
#  'mention of accompanying': 1065412,
#  'of accompanying votes': 1168271,
#  'accompanying votes on': 42964,
#  'votes on local': 1953375,
#  'on local property': 1221104,
#  'local property tax': 1016254,
#  'property tax freeze': 1361387,
#  'tax freeze or': 1634462,
#  'freeze or workers': 651891,
#  'or workers compensation': 1249324,
#  'workers compensation reforms': 2061010,
#  'compensation reforms that': 396559,
#  'reforms that are': 1407341,
#  'that are two': 1652166,
#  'are two of': 182451,
#  'two of rauner': 1908085,
#  'of rauner key': 1190571,
#  'rauner key demands': 1388734,
#  'key demands under': 960074,
#  'demands under negotiation': 475243,
#  'under negotiation in': 1912827,
#  'negotiation in statement': 1120096,
#  'in statement madigan': 851371,
#  'statement madigan said': 1586923,
#  'madigan said he': 1029104,
#  'said he was': 1475007,
#  'he was encouraged': 755540,
#  'was encouraged by': 1965181,
#  'encouraged by the': 550538,
#  'by the progress': 317938,
#  'the progress in': 1726609,
#  'progress in talks': 1357820,
#  'in talks with': 852033,
#  'talks with durkin': 1630754,
#  'with durkin and': 2041687,
#  'durkin and vowed': 529757,
#  'and vowed to': 153919,
#  'vowed to vote': 1954220,
#  'to vote sunday': 1847930,
#  'vote sunday on': 1950987,
#  'sunday on revenue': 1613495,
#  'on revenue package': 1223830,
#  'revenue package modeled': 1446977,
#  'package modeled on': 1274799,
#  'modeled on the': 1082220,
#  'on the bill': 1225815,
#  'the bill supported': 1682869,
#  'bill supported by': 272727,
#  'supported by the': 1616055,
#  'by the governor': 317646,
#  'the governor and': 1702662,
#  'governor and house': 696227,
#  'and house and': 130399,
#  'house and senate': 805498,
#  'and senate republicans': 145001,
#  'senate republicans durkin': 1511998,
#  'republicans durkin made': 1431563,
#  'durkin made clear': 529758,
#  'made clear in': 1027422,
#  'clear in his': 369036,
#  'in his own': 842544,
#  'his own statement': 790823,
#  'own statement that': 1273439,
#  'statement that there': 1587385,
#  'that there is': 1671265,
#  'there is no': 1759612,
#  'is no agreement': 902474,
#  'no agreement on': 1133208,
#  'agreement on comprehensive': 76888,
#  'on comprehensive budget': 1216830,
#  'comprehensive budget package': 399016,
#  'budget package that': 296634,
#  'package that includes': 1274854,
#  'that includes reforms': 1660225,
#  'includes reforms and': 860572,
#  'reforms and revenue': 1407275,
#  'and revenue contradicting': 143599,
#  'revenue contradicting madigan': 1446867,
#  'contradicting madigan and': 418022,
#  'madigan and painting': 1029088,
#  'and painting dim': 139571,
#  'painting dim outlook': 1276443,
#  'dim outlook for': 495684,
#  'outlook for bipartisan': 1265439,
#  'for bipartisan consensus': 624125,
#  'bipartisan consensus on': 275362,
#  'consensus on sunday': 409144,
#  'on sunday this': 1225148,
#  'sunday this impasse': 1613685,
#  'this impasse can': 1778185,
#  'impasse can only': 829827,
#  'can only be': 331080,
#  'only be resolved': 1236532,
#  'be resolved in': 240904,
#  'resolved in negotiated': 1438144,
#  'in negotiated manner': 846315,
#  'negotiated manner durkin': 1119954,
#  'manner durkin said': 1039038,
#  'durkin said it': 529761,
#  'said it is': 1475798,
#  'it is our': 921837,
#  'is our hope': 904061,
#  'our hope that': 1259123,
#  'hope that democrats': 801606,
#  'that democrats will': 1655299,
#  'democrats will remain': 479351,
#  'will remain at': 2034086,
#  'remain at the': 1416123,
#  'at the negotiating': 209492,
#  'the negotiating table': 1717144,
#  'schumer says budget': 1496620,
#  'says budget deal': 1491444,
#  'budget deal doable': 296195,
#  'deal doable if': 460897,
#  'doable if trump': 509459,
#  'if trump stays': 823594,
#  'trump stays out': 1889018,
#  'stays out of': 1592717,
#  'out of it': 1262843,
#  'of it washington': 1182813,
#  'it washington reuters': 928509,
#  'washington reuters senate': 1975205,
#  'reuters senate democratic': 1445538,
#  'senate democratic leader': 1510886,
#  'democratic leader chuck': 476639,
#  'leader chuck schumer': 985369,
#  'chuck schumer said': 361523,
#  'schumer said on': 1496603,
#  'said on sunday': 1477337,
#  'on sunday he': 1225048,
#  'sunday he believes': 1613314,
#  'he believes lawmakers': 743901,
#  'believes lawmakers could': 262099,
#  'lawmakers could reach': 982008,
#  'could reach short': 428717,
#  'reach short term': 1391437,
#  'short term budget': 1534049,
#  'term budget deal': 1642567,
#  'budget deal by': 296193,
#  'deal by friday': 460833,
#  'by friday if': 312854,
#  'friday if president': 652869,
#  'if president donald': 822254,
#  'president donald trump': 1338186,
#  'donald trump did': 517003,
#  'trump did not': 1876057,
#  'did not meddle': 491858,
#  'not meddle in': 1145775,
#  'meddle in their': 1057471,
#  'in their talks': 854651,
#  'their talks with': 1751993,
#  'talks with poison': 1630777,
#  'with poison pill': 2046523,
#  'poison pill demands': 1317446,
#  'pill demands like': 1307704,
#  'demands like funding': 475160,
#  'like funding for': 1004558,
#  'funding for border': 666325,
#  'for border wall': 624216,
#  'border wall am': 284783,
#  'wall am hopeful': 1956051,
#  'am hopeful that': 98483,
#  'hopeful that we': 802004,
#  'that we can': 1674066,
#  'we can get': 1981793,
#  'can get budget': 330254,
#  'get budget done': 676087,
#  'budget done schumer': 296273,
#  'done schumer said': 519086,
#  'schumer said at': 1496588,
#  'said at news': 1472895,
#  'at news conference': 207795,
#  'news conference the': 1127483,
#  'conference the only': 403164,
#  'the only fly': 1719681,
#  'only fly in': 1237063,
#  'fly in the': 618458,
#  'in the ointment': 853677,
#  'the ointment is': 1719312,
#  'ointment is that': 1213110,
#  'is that the': 908119,
#  'that the president': 1670680,
#  'the president is': 1725064,
#  'president is being': 1339100,
#  'is being little': 894873,
#  'being little heavy': 259468,
#  'little heavy handed': 1012678,
#  'heavy handed and': 762641,
#  'handed and mixing': 716029,
#  'and mixing in': 136209,
#  'mixing in and': 1081195,
#  'in and asking': 835676,
#  'and asking for': 116714,
#  'asking for things': 200671,
#  'for things such': 637840,
#  'things such as': 1772325,
#  'such as the': 1609450,
#  'as the border': 195956,
#  'the border wall': 1683645,
#  'border wall so': 284850,
#  'wall so we': 1956508,
#  'so we ask': 1556904,
#  'we ask him': 1981556,
#  'ask him to': 199194,
#  'him to let': 779661,
#  'to let us': 1826194,
#  'let us do': 997515,
#  'us do our': 1928705,
#  'do our work': 508234,
#  'our work not': 1260766,
#  'work not throw': 2059762,
#  'not throw in': 1149083,
#  'throw in some': 1792794,
#  'in some last': 850936,
#  'some last minute': 1560397,
#  'last minute poison': 975212,
#  'minute poison pills': 1078282,
#  'poison pills that': 1317452,
#  'pills that could': 1307743,
#  'that could undo': 1654774,
#  'could undo it': 429275,
#  'undo it and': 1915063,
#  'it and we': 916747,
#  'and we could': 154463,
#  'we could get': 1982058,
#  'could get this': 427631,
#  'get this done': 677605,
#  'nra calls for': 1156394,
#  'calls for more': 323972,
#  'for more regulation': 631452,
#  'more regulation after': 1092308,
#  'regulation after vegas': 1410441,
#  'after vegas shooting': 68233,
#  'vegas shooting washington': 1936677,
#  'shooting washington reuters': 1533495,
#  'washington reuters the': 1975236,
#  'reuters the national': 1445871,
#  'the national rifle': 1716835,
#  'national rifle association': 1113275,
#  'rifle association said': 1451088,
#  'association said on': 203829,
#  'said on thursday': 1477342,
#  'on thursday devices': 1227869,
#  'thursday devices that': 1793577,
#  'devices that allow': 489600,
#  'that allow semi': 1651237,
#  'allow semi automatic': 89185,
#  'semi automatic rifles': 1509976,
#  'automatic rifles to': 218245,
#  'rifles to function': 1451125,
#  'to function like': 1818580,
#  'function like fully': 665445,
#  'like fully automatic': 1004557,
#  'fully automatic ones': 665047,
#  'automatic ones need': 218238,
#  'ones need tougher': 1235591,
#  'need tougher regulation': 1118628,
#  'tougher regulation and': 1858586,
#  'regulation and it': 1410452,
#  'and it called': 132552,
#  'it called on': 917913,
#  'called on regulators': 322407,
#  'on regulators to': 1223662,
#  'regulators to determine': 1411161,
#  'to determine whether': 1813819,
#  'determine whether the': 488365,
#  'whether the bump': 2009361,
#  'the bump stock': 1684309,
#  'bump stock devices': 298630,
#  'stock devices comply': 1597325,
#  'devices comply with': 489570,
#  'comply with federal': 398832,
#  'with federal law': 2042068,
#  'federal law the': 599759,
#  'law the national': 981141,
#  'rifle association is': 1451085,
#  'association is calling': 203754,
#  'is calling on': 895504,
#  'calling on the': 323570,
#  'on the bureau': 1225858,
#  'the bureau of': 1684358,
#  'bureau of alcohol': 299055,
#  'of alcohol tobacco': 1168728,
#  'alcohol tobacco firearms': 81833,
#  'tobacco firearms and': 1849582,
#  'firearms and explosives': 610383,
#  'and explosives to': 125124,
#  'explosives to immediately': 581031,
#  'to immediately review': 1823097,
#  'immediately review whether': 827678,
#  'review whether these': 1447948,
#  'whether these devices': 2009538,
#  'these devices comply': 1761949,
#  'law the powerful': 981155,
#  'the powerful gun': 1724461,
#  'powerful gun lobby': 1332247,
#  'gun lobby group': 706585,
#  'lobby group said': 1015503,
#  'group said in': 702721,
#  'said in statement': 1475527,
#  'in statement the': 851485,
#  'statement the nra': 1587474,
#  'the nra believes': 1718513,
#  'nra believes that': 1156391,
#  'believes that devices': 262153,
#  'that devices designed': 1655409,
#  'devices designed to': 489572,
#  'designed to allow': 485250,
#  'to allow semi': 1803540,
#  'fully automatic rifles': 665048,
#  'automatic rifles should': 218244,
#  'rifles should be': 1451122,
#  'should be subject': 1535289,
#  'be subject to': 241897,
#  'subject to additional': 1607003,
#  'to additional regulations': 1802842,
#  'additional regulations it': 54482,
#  'regulations it said': 1410809,
#  'white house says': 2017943,
#  'house says tillerson': 808473,
#  'says tillerson to': 1492665,
#  'tillerson to remain': 1796374,
#  'to remain as': 1835195,
#  'remain as secretary': 1416118,
#  'as secretary of': 195063,
#  'secretary of state': 1501940,
#  'of state washington': 1194020,
#  'state washington reuters': 1585960,
#  'washington reuters rex': 1975192,
#  'reuters rex tillerson': 1445456,
#  'rex tillerson will': 1448940,
#  'tillerson will remain': 1796478,
#  'will remain as': 2034085,
#  'of state the': 1193995,
#  'state the white': 1585690,
#  'the white house': 1744703,
#  'white house spokeswoman': 2018018,
#  'house spokeswoman said': 808727,
#  'spokeswoman said on': 1576184,
#  'on thursday amid': 1227781,
#  'thursday amid reports': 1793307,
#  'amid reports tillerson': 105585,
#  'reports tillerson will': 1425486,
#  'tillerson will be': 1796467,
#  'will be removed': 2030802,
#  'be removed in': 240774,
#  'removed in favor': 1418320,
#  'in favor of': 840528,
#  'favor of mike': 595279,
#  'of mike pompeo': 1185691,
#  'mike pompeo who': 1072205,
#  'pompeo who is': 1324172,
#  'who is currently': 2022468,
#  'is currently cia': 896646,
#  'currently cia director': 449459,
#  'cia director when': 362024,
#  'director when the': 498304,
#  'when the president': 2006335,
#  'the president loses': 1725110,
#  'president loses confidence': 1339427,
#  'loses confidence in': 1021362,
#  'confidence in someone': 403434,
#  'in someone they': 850978,
#  'someone they will': 1562766,
#  'they will no': 1770224,
#  'will no longer': 2033304,
#  'no longer serve': 1134759,
#  'longer serve here': 1018587,
#  'serve here white': 1519195,
#  'here white house': 771314,
#  'house spokeswoman sarah': 808728,
#  'spokeswoman sarah sanders': 1576202,
#  'sarah sanders said': 1485939,
#  'sanders said when': 1485349,
#  'said when asked': 1481600,
#  'when asked about': 2004041,
#  'asked about reports': 199479,
#  'about reports of': 37022,
#  'reports of staff': 1425185,
#  'of staff shake': 1193725,
#  'staff shake up': 1578714,
#  'scientists scramble to': 1497178,
#  'scramble to copy': 1497998,
#  'to copy climate': 1811870,
#  'copy climate data': 422558,
#  'climate data before': 371023,
#  'data before trump': 455597,
#  'before trump can': 255379,
#  'trump can make': 1874373,
#  'can make it': 330900,
#  'make it all': 1032856,
#  'it all disappear': 916087,
#  'all disappear donald': 83701,
#  'disappear donald trump': 498943,
#  'donald trump isn': 517298,
#  'trump isn exactly': 1881673,
#  'isn exactly stickler': 912492,
#  'exactly stickler for': 573018,
#  'stickler for facts': 1595368,
#  'for facts and': 626967,
#  'facts and he': 587174,
#  'and he has': 128810,
#  'he has made': 747948,
#  'has made it': 726628,
#  'made it clear': 1027884,
#  'it clear that': 918168,
#  'clear that he': 369270,
#  'that he is': 1658657,
#  'he is not': 749095,
#  'is not convinced': 902833,
#  'not convinced that': 1142558,
#  'convinced that climate': 420667,
#  'that climate change': 1654004,
#  'climate change is': 370914,
#  'change is real': 350055,
#  'is real heck': 905380,
#  'real heck he': 1393507,
#  'heck he doesn': 762705,
#  'he doesn necessarily': 746068,
#  'doesn necessarily even': 512230,
#  'necessarily even believe': 1117377,
#  'even believe that': 564747,
#  'believe that science': 261513,
#  'that science is': 1667692,
#  'science is real': 1496880,
#  'is real maybe': 905388,
#  'real maybe global': 1393630,
#  'maybe global warming': 1050555,
#  'global warming is': 683653,
#  'warming is just': 1960560,
#  'is just chinese': 900804,
#  'just chinese hoax': 950951,
#  'chinese hoax right': 359077,
#  'hoax right and': 797692,
#  'right and the': 1451423,
#  'and the people': 149659,
#  'the people he': 1722231,
#  'people he has': 1294934,
#  'he has picked': 747997,
#  'has picked for': 727652,
#  'picked for his': 1306831,
#  'for his cabinet': 628600,
#  'his cabinet are': 783967,
#  'cabinet are far': 319398,
#  'are far from': 177069,
#  'far from environmentally': 592831,
#  'from environmentally friendly': 656664,
#  'environmentally friendly well': 558222,
#  'friendly well scientists': 654025,
#  'well scientists have': 1993950,
#  'scientists have taken': 1497151,
#  'have taken notice': 739629,
#  'taken notice and': 1627828,
#  'notice and are': 1151552,
#  'and are taking': 116455,
#  'are taking action': 181676,
#  'taking action they': 1628433,
#  'action they are': 49070,
#  'they are scrambling': 1764094,
#  'are scrambling to': 180903,
#  'scrambling to copy': 1498029,
#  'before trump administration': 255368,
#  'trump administration has': 1870623,
#  'administration has the': 56618,
#  'has the chance': 729568,
#  'the chance to': 1686105,
#  'chance to make': 349432,
#  'to make it': 1827168,
#  'it all just': 916111,
#  'all just disappear': 84482,
#  'just disappear the': 951195,
#  'disappear the washington': 498959,
#  'the washington post': 1743969,
#  'washington post reports': 1974847,
#  'post reports the': 1328904,
#  'reports the efforts': 1425445,
#  'the efforts include': 1695581,
#  'efforts include guerrilla': 537693,
#  'include guerrilla archiving': 859661,
#  'guerrilla archiving event': 705351,
#  'archiving event in': 174416,
#  'event in toronto': 567622,
#  'in toronto where': 855270,
#  'toronto where experts': 1857230,
#  'where experts will': 2007520,
#  'experts will copy': 579930,
#  'will copy irreplaceable': 2031417,
#  'copy irreplaceable public': 422562,
#  'irreplaceable public data': 892588,
#  'public data meetings': 1368931,
#  'data meetings at': 455744,
#  'meetings at the': 1062003,
#  'at the university': 209800,
#  'the university of': 1742095,
#  'university of pennsylvania': 1919051,
#  'of pennsylvania focused': 1188616,
#  'pennsylvania focused on': 1292663,
#  'focused on how': 619937,
#  'on how to': 1219901,
#  'how to download': 811926,
#  'to download as': 1814951,
#  'download as much': 522904,
#  'as much federal': 193004,
#  'much federal data': 1101848,
#  'federal data as': 599166,
#  'data as possible': 455586,
#  'as possible in': 193980,
#  'possible in the': 1327590,
#  'in the coming': 852841,
#  'the coming weeks': 1687598,
#  'coming weeks and': 387796,
#  'weeks and collaboration': 1991332,
#  'and collaboration of': 119943,
#  'collaboration of scientists': 380127,
#  'of scientists and': 1192308,
#  'scientists and database': 1497090,
#  'and database experts': 121785,
#  'database experts who': 455970,
#  'experts who are': 579916,
#  'who are compiling': 2019631,
#  'are compiling an': 175988,
#  'compiling an online': 396943,
#  'an online site': 112226,
#  'online site to': 1236132,
#  'site to harbor': 1547618,
#  'to harbor scientific': 1820365,
#  'harbor scientific information': 719556,
#  'scientific information nick': 1497002,
#  'information nick santos': 869629,
#  'nick santos an': 1131316,
#  'santos an environmental': 1485780,
#  'an environmental researcher': 109761,
#  'environmental researcher at': 558156,
#  'researcher at the': 1436129,
#  'university of california': 1919021,
#  'of california at': 1171942,
#  'california at davis': 320197,
#  'at davis is': 205835,
#  'davis is one': 457110,
#  'is one of': 903891,
#  'one of the': 1233754,
#  'of the scientists': 1198047,
#  'the scientists who': 1732848,
#  'scientists who is': 1497202,
#  'who is not': 2022582,
#  'is not risking': 903149,
#  'not risking it': 1147655,
#  'risking it over': 1455416,
#  'it over the': 924092,
#  'over the weekend': 1269247,
#  'the weekend he': 1744465,
#  'weekend he started': 1990942,
#  'he started copying': 753757,
#  'started copying government': 1582454,
#  'copying government climate': 422588,
#  'government climate data': 693839,
#  'climate data onto': 371026,
#  'data onto public': 455782,
#  'onto public server': 1239033,
#  'public server something': 1369831,
#  'server something that': 1519611,
#  'something that seemed': 1563791,
#  'that seemed little': 1667767,
#  'seemed little paranoid': 1507277,
#  'little paranoid to': 1012866,
#  'paranoid to me': 1278979,
#  'to me before': 1827711,
#  'me before all': 1053496,
#  'before all of': 253704,
#  'all of sudden': 84906,
#  'of sudden seems': 1194439,
#  'sudden seems potentially': 1610735,
#  'seems potentially realistic': 1507646,
#  'potentially realistic or': 1330492,
#  'realistic or at': 1396024,
#  'or at least': 1244262,
#  'at least something': 207385,
#  'least something you': 989660,
#  'something you want': 1564063,
#  'you want to': 2089551,
#  'want to hedge': 1958034,
#  'to hedge against': 1821185,
#  'hedge against santos': 762761,
#  'against santos said': 71475,
#  'santos said doing': 1485784,
#  'said doing this': 1473991,
#  'doing this can': 513475,
#  'this can only': 1776236,
#  'only be good': 1236514,
#  'be good thing': 237298,
#  'good thing hopefully': 689613,
#  'thing hopefully they': 1771053,
#  'hopefully they leave': 802123,
#  'they leave everything': 1767011,
#  'leave everything in': 989907,
#  'everything in place': 571453,
#  'in place but': 848098,
#  'place but if': 1308803,
#  'but if not': 304672,
#  'if not we': 822078,
#  'not we re': 1149890,
#  'we re planning': 1984274,
#  're planning for': 1390580,
#  'planning for that': 1312169,
#  'for that michael': 635848,
#  'that michael halpern': 1663146,
#  'michael halpern who': 1069441,
#  'halpern who is': 715004,
#  'who is the': 2022688,
#  'is the deputy': 908319,
#  'the deputy director': 1693244,
#  'deputy director of': 483838,
#  'director of the': 498149,
#  'of the center': 1196097,
#  'the center for': 1685748,
#  'center for science': 344896,
#  'for science and': 634473,
#  'science and democracy': 1496783,
#  'and democracy at': 122195,
#  'democracy at the': 475427,
#  'at the advocacy': 208916,
#  'the advocacy group': 1678110,
#  'advocacy group union': 62060,
#  'group union of': 702961,
#  'union of concerned': 1917072,
#  'of concerned scientists': 1173440,
#  'concerned scientists said': 400276,
#  'scientists said in': 1497173,
#  'said in an': 1475368,
#  'in an email': 835531,
#  'an email that': 109422,
#  'email that the': 546529,
#  'that the people': 1670620,
#  'the people trump': 1722310,
#  'people trump has': 1296995,
#  'trump has picked': 1879214,
#  'has picked to': 727656,
#  'picked to head': 1306887,
#  'to head up': 1821022,
#  'head up government': 757504,
#  'up government agencies': 1923876,
#  'government agencies so': 693425,
#  'agencies so far': 72964,
#  'so far have': 1554408,
#  'far have been': 592891,
#  'have been band': 732994,
#  'been band of': 249192,
#  'band of climate': 227516,
#  'of climate conspiracy': 1172808,
#  'climate conspiracy theorists': 371015,
#  'conspiracy theorists they': 412868,
#  'theorists they have': 1758338,
#  'they have been': 1766387,
#  'have been salivating': 733601,
#  'been salivating at': 252309,
#  'salivating at the': 1482534,
#  'at the possibility': 209581,
#  'the possibility of': 1724176,
#  'possibility of dismantling': 1327161,
#  'of dismantling federal': 1175784,
#  'dismantling federal climate': 503068,
#  'federal climate research': 599024,
#  'climate research programs': 371161,
#  'research programs for': 1436048,
#  'programs for years': 1357470,
#  'for years it': 639868,
#  'years it not': 2080073,
#  'it not unreasonable': 923560,
#  'not unreasonable to': 1149670,
#  'unreasonable to think': 1920852,
#  'to think they': 1845208,
#  'think they would': 1773976,
#  'they would want': 1770531,
#  'would want to': 2071954,
#  'want to take': 1958196,
#  'to take down': 1841923,
#  'take down the': 1626401,
#  'down the very': 522477,
#  'the very data': 1742718,
#  'very data that': 1938316,
#  'data that they': 455874,
#  'that they dispute': 1671464,
#  'they dispute he': 1765491,
#  'dispute he wrote': 503942,
#  'he wrote there': 757107,
#  'wrote there is': 2074911,
#  'there is fine': 1759536,
#  'is fine line': 898386,
#  'fine line between': 609486,
#  'line between being': 1009539,
#  'between being paranoid': 266568,
#  'being paranoid and': 259704,
#  'paranoid and being': 1278940,
#  'and being prepared': 117562,
#  'being prepared and': 259785,
#  'prepared and scientists': 1335470,
#  'and scientists are': 144632,
#  'scientists are doing': 1497101,
#  'are doing their': 176598,
#  'doing their best': 513439,
#  'their best to': 1747028,
#  'best to be': 265224,
#  'to be prepared': 1806622,
#  'be prepared scientists': 240102,
#  'prepared scientists are': 1335540,
#  'scientists are right': 1497103,
#  'are right to': 180773,
#  'right to preserve': 1452783,
#  'to preserve data': 1832192,
#  'preserve data and': 1336327,
#  'data and archive': 455563,
#  'and archive websites': 116339,
#  'archive websites before': 174394,
#  'websites before those': 1987528,
#  'before those who': 255343,
#  'those who want': 1786656,
#  ...}

# %%
monogram = vectorizer1.transform(train_text)
bigram = vectorizer2.transform(train_text)
trigram = vectorizer3.transform(train_text)

# %%
monogram
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 1745278 stored elements and shape (7920, 52816)>

# %% [markdown]
# ***classification analysis***

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
clf = MultinomialNB()

# %%
clf.fit(monogram, train_label)
# Out:
# MultinomialNB()

# %%
monogram_ = vectorizer1.transform(test_text)

# %%
clf.predict(monogram_[0:8])
# Out:
# array([1, 1, 1, 1, 0, 1, 0, 0])

# %%
type(test_label[0:8])
# Out:
# pandas.core.series.Series

# %%
preds1 = clf.predict(monogram_)
type(preds1)
# Out:
# numpy.ndarray

# %%
print(classification_report(test_label, preds1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       973
#            1       0.98      0.98      0.98      1007
#
#     accuracy                           0.98      1980
#    macro avg       0.98      0.98      0.98      1980
# weighted avg       0.98      0.98      0.98      1980

# %%
clf.fit(bigram, train_label)
# Out:
# MultinomialNB()

# %%
bigram_ = vectorizer2.transform(test_text)

# %%
preds2 = clf.predict(bigram_)

# %%
print(classification_report(test_label, preds2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       973
#            1       0.99      0.99      0.99      1007
#
#     accuracy                           0.99      1980
#    macro avg       0.99      0.99      0.99      1980
# weighted avg       0.99      0.99      0.99      1980

# %%
clf.fit(trigram, train_label)
# Out:
# MultinomialNB()

# %%
trigram_ = vectorizer3.transform(test_text)

# %%
preds3 = clf.predict(trigram_)
preds3
# Out:
# array([0, 1, 1, ..., 0, 1, 1], shape=(1980,))

# %%
print(classification_report(test_label, preds3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       973
#            1       0.98      1.00      0.99      1007
#
#     accuracy                           0.99      1980
#    macro avg       0.99      0.99      0.99      1980
# weighted avg       0.99      0.99      0.99      1980
