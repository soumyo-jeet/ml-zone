# %% [markdown]
# ## ***GloVe (Global Vectotrisation for word embeddings)***
# - Learns from a global dataset how often words co-occur in a large corpus
# - Build a co-occurrence matrix X, where
#     - **X[i][j] = number of times word j appears in the context of word i**.
#
# > The large / medium model of eng language defined in spacy supports **GloVe**
# ***

# %%
import pandas as pd
import numpy as np
import spacy

# %% [markdown]
# `Small word model has no words with vectors due to small space...`

# %%
nlp = spacy.load('en_core_web_sm')

# %%
vocabs = [w.text for w in nlp.vocab]
len(vocabs)
# Out:
# 764

# %%
vocabs_with_vec = [w.text for w in nlp.vocab if w.has_vector]
len(vocabs_with_vec)
# Out:
# 0

# %%
nlp = spacy.load('en_core_web_lg')

# %%
vocabs = [w.text for w in nlp.vocab]
len(vocabs)
# Out:
# 764

# %%
vocabs_with_vec = [w.text for w in nlp.vocab if w.has_vector]
len(vocabs_with_vec)
# Out:
# 483

# %%
text = "King's Brother Naliva, did not see tiger in his life. That's gonna be the very first time."

# %%
doc = nlp(text)
doc.vector
# Out:
# array([ 2.49257423e-02,  1.40086442e-01, -6.26299158e-02, -9.58364755e-02,
#         8.62075537e-02,  6.23040497e-02,  6.32589161e-02, -2.12972954e-01,
#        -4.82869148e-02,  2.18838739e+00, -2.52835602e-01,  1.56183504e-02,
#         1.36078864e-01, -5.54644410e-03, -1.26936153e-01,  3.23903449e-02,
#         1.67958271e-02,  8.27373505e-01, -1.61599889e-01,  2.16769502e-02,
#         3.49579528e-02, -6.79826587e-02, -3.36050279e-02, -6.44635186e-02,
#         1.58028845e-02,  2.86054332e-02, -7.25458190e-02, -2.21678298e-02,
#         7.24087358e-02, -1.48268405e-03, -9.86358374e-02,  3.72204408e-02,
#        -6.29735067e-02,  3.32303084e-02,  6.76210448e-02, -9.08748358e-02,
#         1.09941661e-01,  3.23800147e-02, -6.57827258e-02, -1.44940242e-01,
#        -6.85887486e-02,  1.83807798e-02,  6.81123659e-02, -1.62720487e-01,
#         6.30724728e-02,  1.51250884e-02, -1.36790395e-01, -3.21125686e-02,
#         5.34656048e-02, -1.76390335e-02, -3.68455402e-03,  5.39165884e-02,
#         3.53638716e-02,  8.40366557e-02,  7.05152601e-02,  7.57356957e-02,
#         1.56446975e-02, -3.61466072e-02,  7.24631846e-02, -6.97299987e-02,
#        -4.30386551e-02, -5.34328371e-02, -5.74852200e-03,  2.48336315e-01,
#         6.71998411e-02, -1.27117429e-02, -1.00113489e-02,  6.90633804e-02,
#        -3.62241752e-02,  1.13341518e-01, -4.88671102e-02,  2.02874448e-02,
#         7.20458850e-02, -5.80409029e-03, -7.90871009e-02,  3.41046154e-02,
#         5.85725680e-02, -3.83868173e-04, -7.81175569e-02,  1.49886265e-01,
#        -7.18573481e-02,  1.83342844e-01, -1.16299398e-01,  8.88692811e-02,
#         1.45002864e-02, -2.56573290e-01,  1.18337385e-01, -3.47332120e-01,
#         1.39739394e-01,  2.32380833e-02, -2.00324371e-01,  5.00051156e-02,
#        -8.88236687e-02,  2.51359995e-02,  1.55414939e-01, -8.27116892e-02,
#         5.38029969e-02, -1.21681564e-01, -4.91203964e-02,  7.04348609e-02,
#        -5.03854863e-02,  1.38180852e-01, -8.47645253e-02, -6.36295676e-02,
#         4.66494337e-02, -3.86974752e-01,  5.06899394e-02,  2.06525344e-02,
#         9.26672146e-02,  1.80586968e-02, -4.90278518e-03,  3.01009556e-03,
#         1.18184807e-02, -1.48703471e-01,  6.32725842e-03, -8.31182450e-02,
#         9.01531950e-02, -7.24092647e-02,  2.98840869e-02,  2.44834833e-02,
#         4.45535034e-03, -5.17786443e-02,  9.47083011e-02,  1.32475160e-02,
#        -4.50220816e-02,  1.04192913e-01, -7.35710412e-02, -2.13030860e-01,
#         4.35017375e-03, -6.32976517e-02, -1.14669595e-02, -1.39774993e-01,
#        -6.66930899e-02, -6.41428754e-02,  1.17409311e-01,  1.19685242e-02,
#         6.45833835e-02,  8.55421573e-02, -6.51839897e-02,  2.98072142e-03,
#        -1.47891569e+00,  6.29047081e-02,  1.18563361e-01,  5.39565086e-02,
#         3.74327339e-02, -4.31061760e-02, -4.95228246e-02,  1.63541064e-01,
#        -1.46742174e-02, -9.58772525e-02, -7.12265670e-02,  6.54775575e-02,
#         1.67823642e-01,  3.74364294e-02, -4.95784804e-02, -4.29630466e-02,
#        -2.04196841e-01, -7.55301490e-02, -2.99234800e-02, -1.05188161e-01,
#        -1.56234773e-02,  2.11586803e-02, -8.58875737e-02, -1.96081754e-02,
#        -3.93863593e-05, -1.69905946e-01,  9.41723958e-02, -3.52130495e-02,
#         1.74427763e-01,  8.94173011e-02, -4.84578349e-02, -5.87569457e-03,
#        -1.76553912e-02, -1.17711298e-01, -1.49752110e-01,  2.56898254e-02,
#         4.60685007e-02,  1.18478695e-02, -1.41915545e-01, -4.89121266e-02,
#         3.00764795e-02, -9.20324847e-02, -1.35711551e-01, -1.00464240e-01,
#        -4.48372252e-02,  1.24175526e-01, -5.88086471e-02, -2.42036991e-02,
#         7.17738718e-02, -5.65795228e-02, -9.13627446e-02,  2.44512688e-03,
#        -1.69844881e-01,  6.06168732e-02,  2.82523111e-02,  8.79344419e-02,
#         3.62846591e-02, -1.94043383e-01, -2.93993670e-02,  1.35422856e-01,
#        -1.01012848e-01,  5.18828630e-02, -7.35649616e-02, -5.36075197e-02,
#         1.74938217e-01, -7.52505586e-02,  9.72466022e-02, -1.66368112e-02,
#        -5.79756238e-02, -2.42537390e-02, -7.91037455e-02, -3.83834727e-02,
#        -1.02179348e-02, -1.96301311e-01,  4.91663106e-02,  9.45605189e-02,
#         4.72121872e-03,  1.80879124e-02, -8.74368623e-02,  1.85897835e-02,
#         5.84749542e-02, -6.68341741e-02, -7.48061240e-02,  6.73419088e-02,
#        -4.60175239e-02,  8.44582096e-02, -5.87852225e-02,  1.60493419e-01,
#        -1.22650396e-02,  1.38384044e-01, -6.32023513e-02,  3.56485210e-02,
#         3.05647366e-02,  7.40537718e-02, -1.63757265e-01, -1.31443113e-01,
#        -9.11006108e-02, -1.27637327e-01, -1.66989684e-01,  5.16989715e-02,
#         6.76917881e-02,  9.76577848e-02,  1.74920559e-02,  1.41069219e-01,
#         1.24880597e-01, -1.57666087e-01, -4.89762612e-03, -1.07298434e-01,
#        -1.31915376e-01,  3.93749550e-02,  1.04340293e-01, -3.40056308e-02,
#        -1.11679852e-01, -2.34614853e-02,  1.25856310e-01,  1.92169607e-01,
#         7.09674135e-03,  1.39053492e-03, -5.12361005e-02,  1.89943668e-02,
#         8.65409970e-02,  1.35162681e-01, -4.02994454e-02,  1.17835358e-01,
#        -3.62913013e-02, -8.53392258e-02,  1.07074725e-02,  6.12791367e-02,
#         2.01143265e-01,  4.40305099e-02,  1.49995103e-01, -3.66391614e-02,
#        -1.07030787e-01, -1.55360088e-01, -6.24062791e-02,  6.02788255e-02,
#        -2.46341955e-02,  1.03144176e-01,  2.67929677e-02,  1.84270695e-01,
#         2.46956497e-01,  7.99458250e-02, -2.50183605e-02, -7.85299763e-02,
#        -3.67184132e-02, -6.44326583e-02,  3.31820808e-02, -4.26536910e-02,
#         1.05300829e-01, -6.53266087e-02, -1.37058541e-01,  1.47217819e-02,
#        -9.91359204e-02, -5.46911173e-02,  1.09293431e-01,  7.59356990e-02,
#        -3.30223404e-02,  5.89164384e-02,  5.73843010e-02,  1.15587618e-02],
#       dtype=float32)

# %%
base_token= nlp("Lion")
for token in doc:
    print(f"{token.text} -> {base_token.text} => {token.similarity(base_token)}")
# Out:
# King -> Lion => 0.4747401773929596
# 's -> Lion => 0.1708216369152069
# Brother -> Lion => 0.29921838641166687
# Naliva -> Lion => 0.0
# , -> Lion => 0.09471897035837173
# did -> Lion => 0.24573396146297455
# not -> Lion => 0.24010586738586426
# see -> Lion => 0.26982855796813965
# tiger -> Lion => 0.7359829545021057
# in -> Lion => 0.1637919545173645
# his -> Lion => 0.27939265966415405
# life -> Lion => 0.24868765473365784
# . -> Lion => 0.17546972632408142
# That -> Lion => 0.23986424505710602
# 's -> Lion => 0.1708216369152069
# gon -> Lion => 0.13697659969329834
# na -> Lion => 0.09639988094568253
# be -> Lion => 0.20266763865947723
# the -> Lion => 0.2469848245382309
# very -> Lion => 0.1867997795343399
# first -> Lion => 0.18334393203258514
# time -> Lion => 0.18702884018421173
# . -> Lion => 0.17546972632408142
# C:\Users\SOUMYOJEET\AppData\Local\Temp\ipykernel_51848\285969939.py:3: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   print(f"{token.text} -> {base_token.text} => {token.similarity(base_token)}")

# %%
modified_text = " ".join([token.lemma_ for token in doc if not token.is_stop and not token.is_punct and not token.is_oov])
modified_doc = nlp(modified_text)
for token in modified_doc:
    print(f"{token} -> {base_token.text} => {token.similarity(base_token)}")
# Out:
# King -> Lion => 0.4747401773929596
# Brother -> Lion => 0.29921838641166687
# tiger -> Lion => 0.7359829545021057
# life -> Lion => 0.24868765473365784
# go -> Lion => 0.23744122684001923
# to -> Lion => 0.1585528552532196
# time -> Lion => 0.18702884018421173

# %% [markdown]
# ## **Exercise with classification**

# %% [markdown]
# ***Data modifications***

# %%
data = pd.read_json('news.json')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7500 entries, 0 to 7499
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      7500 non-null   object
#  1   category  7500 non-null   object
# dtypes: object(2)
# memory usage: 175.8+ KB

# %%
data['category'].value_counts()
# Out:
# category
# CRIME       2500
# SPORTS      2500
# BUSINESS    2500
# Name: count, dtype: int64

# %%
def vectorize(text):
    doc = nlp(text)
    vectors = doc.vector
    return vectors

def map(text):
    if text == "CRIME":
        return 0
    elif text == "SPORTS":
        return 1
    else:
        return 2

# %%
data["text_vect"] = data["text"].apply(vectorize)

# %%
data['text_vect'][0]
# Out:
# array([-1.26001850e-01,  2.67008185e-01, -1.66271344e-01, -6.34676814e-02,
#         1.11337133e-01,  7.27505758e-02,  6.63272515e-02, -2.29737118e-01,
#        -1.11820459e-01,  2.11998129e+00, -1.75150022e-01,  1.19103529e-02,
#         1.03851162e-01, -7.35084713e-02, -2.37800658e-01, -9.46056750e-03,
#        -7.55394101e-02,  6.05688155e-01, -1.07233554e-01,  2.65875049e-02,
#        -4.04296704e-02,  2.03981996e-02,  1.85514074e-02, -3.09930388e-02,
#         2.69037182e-03, -1.15703279e-02, -6.55305460e-02, -2.48420443e-02,
#         1.01293482e-01, -1.04971789e-01, -4.93194163e-02, -3.62486579e-02,
#        -1.12083972e-01,  6.22642078e-02,  6.66726306e-02, -3.55293117e-02,
#        -5.75957820e-02,  4.43126373e-02, -1.18519016e-01,  1.38854906e-02,
#        -4.49024001e-03, -1.18816875e-01,  6.14356883e-02, -1.16614714e-01,
#        -1.31945647e-02,  5.73158786e-02, -1.58320993e-01, -3.14859636e-02,
#         1.05353110e-01,  8.28966592e-03, -8.78614113e-02,  5.73272184e-02,
#        -1.15606472e-01,  6.98404238e-02, -4.90667531e-03,  6.35135099e-02,
#         2.00013854e-02, -1.11459672e-01,  3.90929878e-02, -1.02292478e-01,
#        -8.22227076e-02, -1.40683219e-01,  6.50197715e-02,  7.34758154e-02,
#         8.07459429e-02, -1.24415934e-01,  8.38597585e-03, -5.90283312e-02,
#        -2.49341521e-02,  1.29327312e-01,  3.67665850e-02,  3.34290862e-02,
#         1.03820875e-01, -5.99343516e-02,  3.64480242e-02, -5.60193993e-02,
#         1.20288275e-01, -2.89420206e-02, -6.76614642e-02,  1.44419342e-01,
#        -6.05978034e-02,  6.29305765e-02, -7.04760477e-02, -3.55473980e-02,
#         3.61001007e-02, -2.30830774e-01,  1.56907544e-01, -3.92364085e-01,
#         1.66889206e-01,  6.74220398e-02,  1.41461066e-03,  3.35828820e-03,
#        -1.41048701e-02,  3.65600884e-02,  9.49919447e-02, -9.94400680e-02,
#        -6.68854266e-02,  2.11686064e-02, -8.43518004e-02, -2.77361255e-02,
#        -7.36079812e-02,  1.43617645e-01, -4.27171914e-03, -6.07021488e-02,
#         4.21606563e-02, -4.00811970e-01, -4.90154810e-02, -2.45171972e-02,
#        -1.76629964e-02,  5.45151271e-02, -2.14690547e-02,  3.26844566e-02,
#         4.61359918e-02, -1.86951801e-01, -1.45204999e-02, -1.50861479e-02,
#         6.43617585e-02, -1.16615593e-01, -9.54622170e-04, -3.15662324e-02,
#         9.17456076e-02,  5.08869924e-02,  1.02438323e-01, -7.60727152e-02,
#         3.75712216e-02,  1.21515587e-01,  2.17903834e-02, -1.77138284e-01,
#         3.13058845e-03,  4.15195338e-03, -4.80604395e-02,  1.39215663e-02,
#        -1.09591916e-01,  5.51635288e-02,  9.50177461e-02,  7.37883821e-02,
#        -2.84350719e-02, -1.32268630e-02, -3.08247469e-02,  2.60007493e-02,
#        -1.30566669e+00,  8.34888518e-02,  1.44293875e-01,  4.58165891e-02,
#        -7.29381517e-02,  5.38759120e-03, -6.58524828e-03,  6.42153546e-02,
#        -1.42443717e-01, -1.52294442e-01, -4.15658429e-02,  4.13530134e-02,
#         7.47138485e-02,  5.44814579e-02,  2.71271709e-02,  3.21932621e-02,
#        -1.22971848e-01, -1.32043749e-01, -3.19294035e-02, -8.02374855e-02,
#        -1.03518493e-01, -2.82310601e-03,  8.27535391e-02, -2.58095451e-02,
#        -2.07502902e-01, -4.74857204e-02,  9.18633305e-03, -5.36846854e-02,
#         3.82448994e-02, -1.56434290e-02, -6.89322203e-02, -7.57839084e-02,
#         2.82067843e-02, -3.77583392e-02, -7.51516595e-02,  1.42670628e-02,
#        -2.03398243e-02, -8.01177844e-02, -1.48972854e-01, -9.46403816e-02,
#        -4.22767289e-02, -7.67357871e-02, -1.27689987e-01, -2.36795912e-03,
#         1.62947960e-02, -1.10738212e-02, -1.34764158e-03,  1.43442303e-01,
#         3.46582681e-02,  2.44451035e-02,  7.24421581e-03, -9.87445563e-03,
#        -8.57011825e-02,  6.31824285e-02,  4.13754173e-02,  2.94711646e-02,
#         2.25788504e-02, -1.72952428e-01, -7.53846392e-02,  1.16470225e-01,
#        -2.93448418e-02, -6.27957880e-02, -6.09350242e-02, -1.10045830e-02,
#         8.26768428e-02, -1.75073035e-02,  2.93567106e-02, -3.18194367e-02,
#         9.89000276e-02, -2.85885613e-02, -5.82560040e-02, -1.19268797e-01,
#        -2.30298247e-02,  1.89465024e-02,  1.69585690e-01,  6.52061328e-02,
#        -1.75759196e-02, -9.11306292e-02, -1.59579083e-01, -8.21294188e-02,
#        -4.58805170e-03,  1.20733373e-01, -3.93307842e-02, -1.74700264e-02,
#        -8.61474276e-02,  4.95377788e-03, -8.71245656e-03,  9.86628309e-02,
#        -1.76280197e-02, -7.48461857e-02, -1.47523060e-01,  5.03039323e-02,
#         1.16234042e-01,  2.65159216e-02, -9.34863910e-02, -4.82400879e-02,
#         3.29029886e-03, -6.02816604e-02, -1.75506882e-02,  7.79001117e-02,
#         7.56508438e-03,  5.23099070e-03,  1.80641152e-02,  9.68738738e-03,
#         1.12456076e-01, -7.80600384e-02, -4.74490598e-02, -9.80824605e-02,
#        -1.27508521e-01,  2.04691157e-01,  1.08670205e-01, -2.04093903e-02,
#        -1.88506898e-02, -2.43580397e-02,  3.63697186e-02, -8.60561617e-03,
#        -2.43900362e-02, -4.99720983e-02, -5.74729405e-02,  3.67864594e-02,
#         1.40493408e-01,  5.91548532e-02,  4.61062901e-02,  8.08321685e-02,
#        -6.57794671e-03, -6.44640401e-02, -3.28513305e-03,  1.23958020e-02,
#         1.34311810e-01,  4.46426310e-02,  3.99750508e-02, -1.46468982e-01,
#        -7.92525038e-02, -1.21615522e-01, -1.12027302e-01, -4.17921320e-02,
#        -8.82693566e-03,  1.04092257e-02, -4.26544137e-02,  2.29415223e-01,
#         1.97115213e-01, -4.34727632e-02,  6.64999261e-02, -1.46545157e-01,
#        -1.16463145e-02, -3.18110622e-02,  5.78062888e-03, -6.91446736e-02,
#         6.63856864e-02,  6.30308539e-02, -8.30902308e-02,  1.03038251e-02,
#        -7.10155256e-03,  2.79304590e-02,  1.17756598e-01, -5.04493937e-02,
#        -5.94480969e-02,  5.27221933e-02, -2.70910449e-02,  2.14504618e-02],
#       dtype=float32)

# %%
data['category'] = data['category'].apply(map)

# %%
data.head()
# Out:
#                                                 text  category  \
# 0  Larry Nassar Blames His Victims, Says He 'Was ...         0
# 1       Woman Beats Cancer, Dies Falling From Horse          0
# 2  Vegas Taxpayers Could Spend A Record $750 Mill...         1
# 3  This Richard Sherman Interception Literally Sh...         1
# 4  7 Things That Could Totally Kill Weed Legaliza...         2
#
#                                            text_vect
# 0  [-0.12600185, 0.2670082, -0.16627134, -0.06346...
# 1  [-0.15009212, 0.39993936, -0.030083999, 0.0827...
# 2  [0.0686294, 0.079817496, -0.10145511, -0.09158...
# 3  [-0.05209184, 0.2640776, 0.024623524, -0.05012...
# 4  [-0.1287915, 0.17678502, -0.064180195, -0.1208...

# %% [markdown]
# ***train test split***

# %%
from sklearn.model_selection import train_test_split

# %%
train_text, test_text, train_cat, test_cat = train_test_split(data['text_vect'], data['category'], test_size=0.2, random_state=42)

# %%
train_text, train_cat
# Out:
# (4664    [-0.12581278, 0.1898045, -0.036296602, -0.0293...
#  4411    [-0.07932585, 0.17766216, -0.11637992, -0.0280...
#  7448    [-0.12062322, 0.28803593, -0.09285785, 0.06842...
#  1919    [-0.11157667, 0.22581784, -0.050059576, 0.1048...
#  1298    [0.040780935, 0.079157814, -0.078565314, 0.062...
#                                ...
#  5191    [-0.15780966, 0.1636805, -0.018735997, 0.01396...
#  5226    [-0.008577629, 0.16997755, -0.18298985, -0.023...
#  5390    [-0.117595, 0.31183338, 0.029610638, -0.013123...
#  860     [-0.020720065, 0.17224072, -0.18227829, -0.049...
#  7270    [-0.14791192, 0.086226225, -0.2055983, -0.0767...
#  Name: text_vect, Length: 6000, dtype: object,
#  4664    1
#  4411    0
#  7448    0
#  1919    1
#  1298    1
#         ..
#  5191    0
#  5226    2
#  5390    0
#  860     2
#  7270    2
#  Name: category, Length: 6000, dtype: int64)

# %% [markdown]
# ***train test X fix***

# %%
train_stack = np.stack(train_text) # model requires 2-D array as X
test_stack = np.stack(test_text)
test_stack
# Out:
# array([[ 0.06671583,  0.1412695 , -0.11733154, ..., -0.11196616,
#         -0.03278363, -0.00393685],
#        [-0.01368161,  0.05240081,  0.08033022, ...,  0.01986429,
#         -0.08102372,  0.1284342 ],
#        [-0.02073403,  0.12885685, -0.12046428, ..., -0.0283075 ,
#          0.05703985,  0.05961888],
#        ...,
#        [-0.06178999,  0.20459999, -0.11497214, ..., -0.0450891 ,
#         -0.00802652,  0.12298948],
#        [-0.06142196,  0.19728164, -0.12341338, ..., -0.1150021 ,
#          0.0386393 ,  0.07016914],
#        [-0.10421622,  0.19685285, -0.01277222, ..., -0.01948734,
#          0.13160922,  0.0942944 ]], shape=(1500, 300), dtype=float32)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
scaled_train_stack = scaler.fit_transform(train_stack)
scaled_test_stack = scaler.transform(test_stack)

scaled_train_stack
# Out:
# array([[0.416151  , 0.58160686, 0.3055647 , ..., 0.45544875, 0.45612225,
#         0.48931414],
#        [0.47877282, 0.568594  , 0.23375559, ..., 0.4453909 , 0.47794566,
#         0.5037934 ],
#        [0.42314178, 0.6868806 , 0.25484735, ..., 0.43832693, 0.40509003,
#         0.43344137],
#        ...,
#        [0.42722106, 0.7123841 , 0.3646624 , ..., 0.5352946 , 0.3619061 ,
#         0.4402717 ],
#        [0.55771977, 0.5627839 , 0.17466584, ..., 0.4690867 , 0.46605614,
#         0.49818766],
#        [0.38638163, 0.4706029 , 0.15375525, ..., 0.42784762, 0.36653465,
#         0.40723234]], shape=(6000, 300), dtype=float32)

# %% [markdown]
# ***Classification***

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# `KNN` - 89 %
# ***
# - Unscaled data

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf_1 = KNeighborsClassifier(n_neighbors=5, metric='cosine')

# %%
clf_1.fit(train_stack, train_cat)
# Out:
# KNeighborsClassifier(metric='cosine')

# %%
preds_1 = clf_1.predict(test_stack)
preds_1[:10], test_cat[:10]
# Out:
# (array([1, 0, 2, 2, 1, 2, 1, 2, 0, 0]),
#  970     1
#  6279    0
#  1859    2
#  6803    2
#  6305    1
#  3039    2
#  7194    1
#  1446    2
#  5199    0
#  6234    0
#  Name: category, dtype: int64)

# %%
print(classification_report(test_cat, preds_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90       510
#            1       0.90      0.85      0.87       482
#            2       0.89      0.90      0.90       508
#
#     accuracy                           0.89      1500
#    macro avg       0.89      0.89      0.89      1500
# weighted avg       0.89      0.89      0.89      1500

# %% [markdown]
# - Scaled data

# %%
clf_1.fit(scaled_train_stack, train_cat)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
preds_1_ = clf_1.predict(scaled_test_stack)
preds_1_[:10], test_cat[:10]
# Out:
# (array([1, 0, 2, 2, 2, 2, 1, 2, 0, 0]),
#  970     1
#  6279    0
#  1859    2
#  6803    2
#  6305    1
#  3039    2
#  7194    1
#  1446    2
#  5199    0
#  6234    0
#  Name: category, dtype: int64)

# %%
print(classification_report(test_cat, preds_1_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       510
#            1       0.91      0.84      0.87       482
#            2       0.88      0.92      0.90       508
#
#     accuracy                           0.89      1500
#    macro avg       0.89      0.89      0.89      1500
# weighted avg       0.89      0.89      0.89      1500

# %% [markdown]
# `Multinomial Naive Bayes` - ***83 %***
# ***
# - Scaled data
#     - non scaled data is not possible as the model can't feed with neg values

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf_2 = MultinomialNB()

# %%
clf_2.fit(scaled_train_stack, train_cat)
# Out:
# MultinomialNB()

# %%
preds_2 = clf_2.predict(scaled_test_stack)

# %%
print(classification_report(test_cat, preds_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86       510
#            1       0.86      0.80      0.83       482
#            2       0.76      0.88      0.82       508
#
#     accuracy                           0.83      1500
#    macro avg       0.84      0.83      0.83      1500
# weighted avg       0.84      0.83      0.83      1500

# %% [markdown]
# `Random Forest Regressor` - ***88 %***

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf_3 = RandomForestClassifier()

# %%
clf_3.fit(train_stack, train_cat)
# Out:
# RandomForestClassifier()

# %%
preds_3 = clf_3.predict(test_stack)

# %%
print(classification_report(test_cat, preds_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88       510
#            1       0.87      0.90      0.88       482
#            2       0.88      0.89      0.89       508
#
#     accuracy                           0.88      1500
#    macro avg       0.88      0.88      0.88      1500
# weighted avg       0.89      0.88      0.88      1500

# %% [markdown]
# - scaled data

# %%
clf_3.fit(scaled_train_stack, train_cat)
# Out:
# RandomForestClassifier()

# %%
preds_3_ = clf_3.predict(scaled_test_stack)

# %%
print(classification_report(test_cat, preds_3_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88       510
#            1       0.86      0.89      0.87       482
#            2       0.88      0.89      0.89       508
#
#     accuracy                           0.88      1500
#    macro avg       0.88      0.88      0.88      1500
# weighted avg       0.88      0.88      0.88      1500

# %% [markdown]
# `Decision Tree Classifier` - **73 %**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf_4 = DecisionTreeClassifier()

# %%
clf_4.fit(train_stack, train_cat)
# Out:
# DecisionTreeClassifier()

# %%
preds_4 = clf_4.predict(test_stack)

# %%
print(classification_report(test_cat, preds_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.70      0.73       510
#            1       0.71      0.74      0.72       482
#            2       0.73      0.75      0.74       508
#
#     accuracy                           0.73      1500
#    macro avg       0.73      0.73      0.73      1500
# weighted avg       0.73      0.73      0.73      1500
